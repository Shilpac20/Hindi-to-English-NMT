# %% [markdown]
# **Load Data and do preprocessing**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
dataset=pd.read_csv('/content/drive/MyDrive/train.csv',encoding='utf-8',usecols=['hindi','english'])
dataset.head()
# Out:
#                                                hindi                                            english
# 0  एल सालवाडोर मे, जिन दोनो पक्षों ने सिविल-युद्ध...  In El Salvador, both sides that withdrew from ...
# 1                मैं उनके साथ कोई लेना देना नहीं है.                    I have nothing to do with them.
# 2                                         -हटाओ रिक.                                   Fuck them, Rick.
# 3               क्योंकि यह एक खुशियों भरी फ़िल्म है.                         Because it's a happy film.
# 4                   The thought reaching the eyes...                   The thought reaching the eyes...

# %% [markdown]
# **Pre-requisite for hindi text processing**

# %%
# !git clone "https://github.com/anoopkunchukuttan/indic_nlp_library"
# !git clone https://github.com/anoopkunchukuttan/indic_nlp_resources.git
# !pip install Morfessor
# The path to the local git repo for Indic NLP library
INDIC_NLP_LIB_HOME=r"/content/indic_nlp_library"

# The path to the local git repo for Indic NLP Resources
INDIC_NLP_RESOURCES="/content/indic_nlp_resources"
import sys
sys.path.append(r'{}'.format(INDIC_NLP_LIB_HOME))
from indicnlp import common
common.set_resources_path(INDIC_NLP_RESOURCES)
from indicnlp import loader
loader.load()
# Out:
# Cloning into 'indic_nlp_library'...
# remote: Enumerating objects: 1271, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 1271 (delta 50), reused 54 (delta 25), pack-reused 1178
# Receiving objects: 100% (1271/1271), 9.56 MiB | 12.39 MiB/s, done.
# Resolving deltas: 100% (654/654), done.
# Cloning into 'indic_nlp_resources'...
# remote: Enumerating objects: 133, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 133 (delta 0), reused 2 (delta 0), pack-reused 126
# Receiving objects: 100% (133/133), 149.77 MiB | 32.77 MiB/s, done.
# Resolving deltas: 100% (51/51), done.
# Checking out files: 100% (28/28), done.
# Collecting Morfessor
#   Downloading https://files.pythonhosted.org/packages/39/e6/7afea30be2ee4d29ce9de0fa53acbb033163615f849515c0b1956ad074ee/Morfessor-2.0.6-py3-none-any.whl
# Installing collected packages: Morfessor
# Successfully installed Morfessor-2.0.6

# %%
import re
import string
import random
from unicodedata import normalize
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory
from indicnlp.tokenize import indic_tokenize

# %% [markdown]
# **Building the vocabulary and also assigning indexes to each word including start token(SOS_token) and end token(EOS_token)**

# %%
SOS_token = 0
EOS_token = 1

class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %% [markdown]
# **Pre-processing the text of both source and target language like tokenizing the text , removing quotes or other punctuations present**

# %% [markdown]
# *   The function pre_process_english_sentence takes in each english sentence and tokenises the words and removes all the unnecessary things like punctuation marks, numbers, quotes.
# *   Similarly , pre_process_hindi_sentence takes in each hindi sentence and tokenises using indic tokeniser and returns the processed sentence.
#
#
# *  The to_pairs function takes in the dataframe object containing out input dataset and it returns a list of lists containing processed source and target input sentences.

# %%
def to_pairs(df):
    english_lines =df['english'].tolist()
    hindi_lines = df['hindi'].tolist()
    pairs = []
    for i in range(len(hindi_lines)):
        pairs.append([])
        pairs[i].append(pre_process_hindi_sentence(hindi_lines[i]))
        pairs[i].append(pre_process_english_sentence(english_lines[i]))
    return pairs

def clean_text(text):
    text = text.replace(u',','')
    text = text.replace(u'"','')
    text = text.replace(u'"','')
    text = text.replace(u"‘‘",'')
    text = text.replace(u"’’",'')
    text = text.replace(u"''",'')
    text = text.replace(u"।",'')
    text=text.replace(u',','')
    text=text.replace(u'"','')
    text=text.replace(u'(','')
    text=text.replace(u')','')
    text=text.replace(u'"','')
    text=text.replace(u':','')
    text=text.replace(u"'",'')
    text=text.replace(u"‘‘",'')
    text=text.replace(u"’’",'')
    text=text.replace(u"''",'')
    text=text.replace(u".",'')
    text=text.replace(u"-",'')
    text=text.replace(u"।",'')
    text=text.replace(u"?",'')
    text=text.replace(u"\\",'')
    text=text.replace(u"_",'')
    text=text.replace("'", "")
    text=text.replace('"', "")
    text= re.sub("'", '', text)
    text= re.sub("’", '', text)
    text=re.sub('[0-9+\-*/.%]', '', text)
    text=text.strip()
    text=re.sub(' +', ' ',text)
    exclude = set(string.punctuation)
    text= ''.join(ch for ch in text if ch not in exclude)
    return text
def pre_process_english_sentence(line):
    line = line.lower()
    line = clean_text(line)
    re_print = re.compile('[^%s]' % re.escape(string.printable))
    line = normalize('NFD', line).encode('ascii', 'ignore')
    line = line.decode('UTF-8')
    line = line.split()
    line = [re_print.sub('', w) for w in line]
    line = [word for word in line if word.isalpha()]
    line = ' '.join(line)
    return line

def pre_process_hindi_sentence(line):
    #print(line)
    #line=re.sub('[^a-zA-Z]', '', line)
    #print(line)
    line = clean_text(line)
    #remove_nuktas = False
    factory = IndicNormalizerFactory()
    normalizer = factory.get_normalizer("hi",remove_nuktas=False)
    line = normalizer.normalize(line)
    
    
    tokens = list()
    for t in indic_tokenize.trivial_tokenize(line):
        tokens.append(t)
    line = tokens
    line = [word for word in line if not re.search(r'\d', word)]
    line = ' '.join(line)
    return (line)

def prepareData(pairs):
    input_lang = Lang('hin')
    output_lang = Lang('eng')
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    return input_lang, output_lang


pairs_all = to_pairs(dataset)
input_lang, output_lang = prepareData(pairs_all)

# %%
l=pre_process_hindi_sentence('क्योंकि यह एक खुशियों भरी फ़िल्म है	')
l
# Out:
# 'क्योंकि यह एक खुशियों भरी फ़िल्म है'

# %%
print(pairs_all[0][0].split(' '))
# Out:
# ['एल', 'सालवाडोर', 'मे', 'जिन', 'दोनो', 'पक्षों', 'ने', 'सिविलयुद्ध', 'से', 'वापसी', 'ली', 'उन्होंने', 'वही', 'काम', 'किये', 'जो', 'कैदियों', 'की', 'कश्मकश', 'के', 'निदान', 'हैं']

# %% [markdown]
# **Lang object's n_words tells us the vocabulary size of source(Hindi) and target(English) language**

# %%
input_lang.n_words
# Out:
# 46183

# %%
output_lang.n_words
# Out:
# 32594

# %%
import numpy as np

# %% [markdown]
# Here I am checking the maximum sentence length of source(hindi) and target(english)

# %%
df = pd.DataFrame(pairs_all)
df.columns = ["hindi", "english"]
lines = df
lenght_list=[]
for l in lines.hindi:
    lenght_list.append(len(l.split(' ')))
max_length_src = np.max(lenght_list)
print (max_length_src)
lenght_list=[]
for l in lines.english:
    lenght_list.append(len(l.split(' ')))
max_length_tar = np.max(lenght_list)
print (max_length_tar)
df.head()
# Out:
# 394
# 301
#                                                hindi                                            english
# 0  एल सालवाडोर मे जिन दोनो पक्षों ने सिविलयुद्ध स...  in el salvador both sides that withdrew from t...
# 1                 मैं उनके साथ कोई लेना देना नहीं है                     i have nothing to do with them
# 2                                           हटाओ रिक                                     fuck them rick
# 3                क्योंकि यह एक खुशियों भरी फ़िल्म है                           because its a happy film
# 4                      The thought reaching the eyes                      the thought reaching the eyes

# %% [markdown]
# **Starting the Model**

# %% [markdown]
# **Encoder**

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# **Decoder**

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        output = self.embedding(input).view(1, 1, -1)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# **Attention Decoder**

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=output_lang.n_words):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, hidden = self.gru(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# **We have prepared input output pairs which are strings but input to our model should be tensors. So need to convert to tensors**

# %%
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]


def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)


def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %% [markdown]
# **Training our model**

# %% [markdown]
# I have used teacher_forcing here , teacher_forcing basically ensures that at certain sequence time say t the input to the decoder is the actual word instead of the word decoded by the decoder in the previous sequence step (t-1).

# %%
teacher_forcing_ratio = 0.5


def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=output_lang.n_words):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %% [markdown]
# The asMinutes and timeSince functions are mainly used to see the time spent in each epoch

# %%
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %%
def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every
   
    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    criterion = nn.NLLLoss()
   
    training_pairs = [tensorsFromPair(random.choice(pairs_all))
                        for i in range(n_iters)]
      

    for iter in range(1, n_iters + 1):
          training_pair = training_pairs[iter - 1]
          input_tensor = training_pair[0]
          target_tensor = training_pair[1]

          loss = train(input_tensor, target_tensor, encoder,
                      decoder, encoder_optimizer, decoder_optimizer, criterion)
          print_loss_total += loss
          plot_loss_total += loss

          if iter % print_every == 0:
              print_loss_avg = print_loss_total / print_every
              print_loss_total = 0
              print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                          iter, iter / n_iters * 100, print_loss_avg))

          if iter % plot_every == 0:
              plot_loss_avg = plot_loss_total / plot_every
              plot_losses.append(plot_loss_avg)
              plot_loss_total = 0

    return plot_losses

# %% [markdown]
# **Evaluation**

# %%
def evaluate(encoder, decoder, sentence, max_length=output_lang.n_words):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]

# %% [markdown]
# evaluateRandomly function I used to check the encoder decoder setting after I trained my model for few epochs. It evaluates the model by taking into consideration random inputs from training set

# %%
def evaluateRandomly(encoder, decoder, n=10,pairs_all=pairs_all):
  list_output=[]
  list_target=[]
  for i in range(n):
        pair = random.choice(pairs_all)
        print('Source : ', pair[0])
        print('Original Output :', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        print('Our Translation :', output_sentence)
        list_output.append(output_sentence)
        list_target.append(pair[1])
        print('')
  return list_output,list_target

# %% [markdown]
# **Train and Evaluate**

# %% [markdown]
# Here , I have intialised my encoder and decoder and started training my model. I have printed the loss after every 10000 iterations.

# %%
hidden_size = 256
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)
encoder1.load_state_dict(torch.load('/content/drive/MyDrive/myencoder_new.pt'))
attn_decoder1.load_state_dict(torch.load('/content/drive/MyDrive/mydecoder_new.pt'))
for epoch in range(4):
  print("Epoch ",epoch," started")
  loss=trainIters(encoder1, attn_decoder1, 102321, print_every=10000)
  torch.save(encoder1.state_dict(), '/content/drive/MyDrive/myencoder_new.pt')
  torch.save(attn_decoder1.state_dict(), '/content/drive/MyDrive/mydecoder_new.pt')
  print("Epoch ",epoch," ended")
# Out:
# Epoch  0  started
# 10m 53s (- 100m 31s) (10000 9%) 3.4415
# 21m 29s (- 88m 29s) (20000 19%) 3.4050
# 32m 17s (- 77m 51s) (30000 29%) 3.4386
# 42m 52s (- 66m 48s) (40000 39%) 3.3864
# 53m 35s (- 56m 4s) (50000 48%) 3.4343
# 64m 7s (- 45m 13s) (60000 58%) 3.4085
# 74m 45s (- 34m 30s) (70000 68%) 3.3866
# 85m 12s (- 23m 46s) (80000 78%) 3.3626
# 95m 48s (- 13m 6s) (90000 87%) 3.3604
# 106m 17s (- 2m 28s) (100000 97%) 3.3561
# Epoch  0  ended
# Epoch  1  started
# 10m 44s (- 99m 7s) (10000 9%) 3.3706
# 21m 20s (- 87m 51s) (20000 19%) 3.3244
# 31m 58s (- 77m 4s) (30000 29%) 3.3210
# 42m 33s (- 66m 17s) (40000 39%) 3.3264
# 53m 8s (- 55m 36s) (50000 48%) 3.3273
# 63m 40s (- 44m 54s) (60000 58%) 3.3128
# 74m 26s (- 34m 22s) (70000 68%) 3.3133
# 85m 6s (- 23m 44s) (80000 78%) 3.3197
# 95m 54s (- 13m 7s) (90000 87%) 3.3081
# 106m 32s (- 2m 28s) (100000 97%) 3.2999
# Epoch  1  ended
# Epoch  2  started
# 10m 40s (- 98m 34s) (10000 9%) 3.2823
# 21m 23s (- 88m 3s) (20000 19%) 3.2729
# 32m 16s (- 77m 47s) (30000 29%) 3.2884
# 42m 55s (- 66m 52s) (40000 39%) 3.2529
# 53m 31s (- 56m 0s) (50000 48%) 3.2379
# 64m 17s (- 45m 20s) (60000 58%) 3.2847
# 74m 50s (- 34m 33s) (70000 68%) 3.2542
# 85m 26s (- 23m 50s) (80000 78%) 3.2336
# 95m 57s (- 13m 8s) (90000 87%) 3.1992
# 106m 41s (- 2m 28s) (100000 97%) 3.2493
# Epoch  2  ended
# Epoch  3  started
# 10m 52s (- 100m 21s) (10000 9%) 3.2414
# 21m 45s (- 89m 34s) (20000 19%) 3.2462
# 32m 17s (- 77m 51s) (30000 29%) 3.2224
# 42m 56s (- 66m 54s) (40000 39%) 3.2029
# 53m 38s (- 56m 8s) (50000 48%) 3.2119
# 64m 26s (- 45m 27s) (60000 58%) 3.1918
# 75m 2s (- 34m 38s) (70000 68%) 3.1805
# 85m 31s (- 23m 51s) (80000 78%) 3.1835
# 96m 8s (- 13m 9s) (90000 87%) 3.2018
# 106m 48s (- 2m 28s) (100000 97%) 3.1742
# Epoch  3  ended

# %%
torch.save(encoder1.state_dict(), '/content/drive/MyDrive/myencoder_new.pt')
torch.save(attn_decoder1.state_dict(), '/content/drive/MyDrive/mydecoder_new.pt')

# %% [markdown]
# **Testing time**

# %%
hidden_size = 256
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)

# %% [markdown]
# During test time I loaded the saved model and used the loaded encoder decoder states for predictions.

# %%
encoder1.load_state_dict(torch.load('/content/drive/MyDrive/myencoder_new.pt'))
attn_decoder1.load_state_dict(torch.load('/content/drive/MyDrive/mydecoder_new.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# Here i have checked my model's performance on 10 randomly picked inputs

# %%
list_output,list_target=evaluateRandomly(encoder1, attn_decoder1,10,pairs_all)
# Out:
# Source :  व्यवसाय
# Original Output : business
# Our Translation : business <EOS>
#
# Source :  इस बदबूदार खलिहान में भूल जाओ
# Original Output : forget this stinking barn
# Our Translation : forget this in forget <EOS>
#
# Source :  अब अपनी पोस्ट के लिए वापस जाओ
# Original Output : get back to your post now
# Our Translation : get back to get back <EOS>
#
# Source :  यह कहानी शुरू होती है इन दोनों से मेरे बच्चे
# Original Output : this story starts with these two my kids
# Our Translation : these start starts both starts <EOS>
#
# Source :  ठीक है ऐलिस ठीक हो सकता है नहीं एक अजनबी
# Original Output : okay alice can not be a stranger okay
# Our Translation : okay might be might see just right <EOS>
#
# Source :  गोली मत चलाना मेरे पास कोई गन नहीं है
# Original Output : dont shoot im not armed
# Our Translation : dont have have have have have have have have have have have have have have have have a shoot <EOS>
#
# Source :  और शायद मैनें उन्हें डरा दिया था हँसी क्योंकि उन्होंने कुल मिला कर मुझसे वादा किया कि और मेरे पास तैयार सामग्री नहीं थी मगर वो बोले आर्ट सेक्शन में एक पैराग्राफ़ दें देंगे यदि आप मेरा पीछा छोड दें
# Original Output : and i think i scared him laughter because he basically promised me we had no product but he said well give you a paragraph in the arts section if youll just go away
# Our Translation : laughter and i promised them to laughter will be laughter you laughter maybe if they will be laughter but laughter will not give them up and my few years but my will not give them up and the few years <EOS>
#
# Source :  Macedon के फिलिप के उत्साही उच्च और योग्य
# Original Output : highspirited and worthy of philip of macedon
# Our Translation : philip of the the and <EOS>
#
# Source :  मेरा एक और दोस्त हैं नाम हैं उदो
# Original Output : i have another friend named udo
# Our Translation : my friend friend friend friend <EOS>
#
# Source :  तुम्हारे लिए हल हो क्या गया है
# Original Output : what has to be solved for you
# Our Translation : what what you you for <EOS>

# %%
len(list_output),len(list_target)
# Out:
# (10, 10)

# %%
list_output_temp=[]
i=0
for item in list_output:
  item=item[:-5]
  print(item ," target ->",list_target[i])
  i+=1
  list_output_temp.append(item)
# Out:
# so we have been have been have been have been we have been have been on the women have been have been women and women and women have been women   target -> so we have the old we have the young we have the uprising power of women and theres one megatrend which affects all of us
# and one of the was to to to these to to to   target -> one of the ways they wanted to do it was to put a tracking chip inside one of the whales
# and now indus script script   target -> and the indus script now has this particular property
# okay told me about my didnt give us about about about about about about about about about about about about about about about   target -> okay so they didnt tell us to become doctors or lawyers or anything like that but my dad did read to us about aristotle and pioneer germfighters when lots of other kids were hearing the wheels on the bus go round and round
# i mean mean mean where i meant photo   target -> i mean where was this picture taken
# yeah this was last the last car   target -> yeah it was lodged in the back seat of the car
# while a a working this time together working this working this a working   target -> he got angry with us while working on a film
# cheers the the the the the   target -> cheers for the pep talk coxy yeah
# they looked looked looked at the demographics city of the the the the the the   target -> he looked at the demographics
# laughter so i the the the the the the the the the the the the the the the the the the not the the the the the the   target -> laughter ive spent my life defending the net and i do feel that if we dont fight online crime we are running a risk of losing it all

# %% [markdown]
# Here I have used corpus_blue metric to check my model's performance

# %%
from nltk.translate.bleu_score import corpus_bleu

def bleu(n):
    weights = [1.0/n]*n + [0.0]*(4-n)
    return lambda list_of_references, list_of_hypothesis: corpus_bleu(list_of_references, list_of_hypothesis, weights)

def accuracy(list_of_references, list_of_hypothesis):
    total = 0.0
    for references, hypothesis in zip(list_of_references, list_of_hypothesis):
        total += 1.0 if tuple(hypothesis) in set(references) else 0.0
    return total / len(list_of_references)

score_functions = {'BLEU-{}'.format(i):bleu(i) for i in range(1, 5)}
score_functions['Accuracy'] = accuracy

def score(list_of_hypothesis, target, desc='Scoring...'):
    scores = {name:0.0 for name in score_functions.keys()}
    length = len(target)
    #list_of_hypothesis=list_of_hypothesis[:-1] #reoving eos token
    

    for name, func in score_functions.items():
        score = func(target, list_of_hypothesis)
        scores[name] = score

    return scores

# %%
scores=score(list_output_temp,list_target)
# Out:
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
scores
# Out:
# {'Accuracy': 0.0,
#  'BLEU-1': 0.1794871794871795,
#  'BLEU-2': 0.4236592728681617,
#  'BLEU-3': 0.5640849044411526,
#  'BLEU-4': 0.6508911374939451}

# %% [markdown]
# Here I have checked the sentence_bleu score for my predicted sentences

# %%
import nltk
#import sys
nltk.download('wordnet')
from nltk.translate.bleu_score import sentence_bleu
#from nltk.translate.meteor_score import single_meteor_score
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
total_num = len(list_output_temp)
total_bleu_scores = 0
total_meteor_scores = 0
for i in range(total_num):
  total_bleu_scores+=sentence_bleu([list_target[i].split(" ")], list_output_temp[i].split(" "))
  #total_meteor_scores+=single_meteor_score(list_target[i], list_output_temp[i])

bleu_result = total_bleu_scores/total_num
#meteor_result = total_meteor_scores/total_num

print("bleu score: ",bleu_result)
#print("meteor score: ",meteor_result)
# Out:
# bleu score:  0.4131154606571806
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %% [markdown]
# **Here onwards I have tested my model on the provided dev set**

# %% [markdown]
# Loading the dataset provided and converting it into a list

# %%
hindi_statements=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/hindistatements.csv',encoding='utf-8',usecols=['hindi'])

# %%
test_week1=hindi_statements.values.tolist()

# %% [markdown]
# **Here I have pre-processed the Hindi sentences**

# %%
test_week1_preprocessed=[]

# %%
for i in range(len(test_week1)):
    clean_line=pre_process_hindi_sentence(str(test_week1[i]))
    test_week1_preprocessed.append(clean_line)

# %% [markdown]
# The following function was used to convert the input sentences into tensor objects so that that can be fed into the encoder

# %%
def indexesFromSentence_test(lang, sentence):
    list_index=[]
    for word in sentence.split(' '):
      try:
        list_index.append(lang.word2index[word])
      except:
        continue
    return list_index


def tensorFromSentence_test(lang, sentence):
    indexes = indexesFromSentence_test(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)

# %%
test_week1_tensor=[]
for source_sent in test_week1_preprocessed:
    tensor = tensorFromSentence_test(input_lang, source_sent)
    test_week1_tensor.append(tensor)
#test_week1_tensor = torch.transpose(torch.cat(test_week1_tensor, dim=-1), 1, 0)

# %% [markdown]
# evaluate_test function takes in the encoder and decoder along with the input tensor made in the previous step and the vocabulary of the target language

# %%
def evaluate_test(encoder, decoder, input_tensor, max_length=output_lang.n_words):
    with torch.no_grad():
        #input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]

# %% [markdown]
# **Writing the predictions in answer.txt file**

# %%
examples = zip(test_week1_preprocessed,test_week1_tensor)
file1 = open("/content/drive/MyDrive/answer_27.txt","w")
for source,  x in examples:
    output_words, attentions = evaluate_test(encoder1, attn_decoder1, x)
    output_sentence = ' '.join(output_words)
    source = ' '.join(source)
    

    file1.write(output_sentence+'\n')
    print('Source: "{}"\nTranslation: "{}"\n'.format(source,  output_sentence))
file1.close()
# Out:
# Source: "अ ं त र ि क ् ष   व ा ल े   ल ो ग"
# Translation: "the people <EOS>"
#
# Source: "आ ं ट ी   य े   ख ब र   आ प क ो   ह ी   ब त ा न ा   प ड ़ े ग ा"
# Translation: "and you will you you you <EOS>"
#
# Source: "व े   आ त े   औ र   फ ि ल ् म   द े ख त े"
# Translation: "they called the film <EOS>"
#
# Source: "म ै ं   ज ा न त ा   ह ू ँ   आ प   क ् य ा   स ो च   र ह े   ह ै ं   आ प   स ो च   र ह े   प र   ब स ् त ी   त ो   क ि स ी   औ र   क ी   ज म ी न   प े   क ब ् ज े   स े   ब न त ी   ह ै   म ग र   स ो च ि ए   र ा त   क े   अ ं ध े र े   म े ं   क ब ् ज ा   न ह ी ं   ह ो त ा"
# Translation: "i know you you you you you you you you you you you you you you you you you you you you you you you you you you you <EOS>"
#
# Source: "अ ग र   म ै ं   भ ी   म ु झ े   स े   च ो र ी   क र त े   ह ै ं   ब ा क ी   म े ं   स ो च न े   क े   ल ि ए   क ् य ा   क र   र ह े   ह ै ं"
# Translation: "but i what i do for too <EOS>"
#
# Source: "ब ि द क ा   घ ो ड ़ ा   प ि छ ल ी   ट ा ं ग ो ं   प र   ख ड ़ ा   ह ु आ   छ ठ े   स ् थ ा न   म े ं   स ा ं प   घ ु स ा"
# Translation: "in the the in in in <EOS>"
#
# Source: "म ै ं   व ह ा ँ   ज ल व ा य ु   प र ि व र ् त न   क ी   च र ् च ा   क र न े   ग ई   थ ी   औ र   प ू ं ज ी व ा द   व   र ा ष ् ट ् र ी य   न ि य ं त ् र ण   क ी   च र ् च ा   क र त े   ह ु ए   व ा प स   आ ई"
# Translation: "i was here because climate because because why because and and why <EOS>"
#
# Source: "औ र   उ ह"
# Translation: "uh <EOS>"
#
# Source: "म ु झ े   ल ग त ा   ह ै   व े   त ु म ् ह े ं   ग ि र फ ् त ा र   स े   प ह ल े   आ प   उ स   ख र ् च   क र   स क त े   ह ै ं"
# Translation: "i guess they could get to before they you fight <EOS>"
#
# Source: "स ब   क ु छ   न ह ी ं   ह ै"
# Translation: "nothing is all <EOS>"
#
# Source: "आ प   क ह   स क त े   ह ै ं   ठ ी क   ह ै   य ह   ब ु र ा   ह ै   ल े क ि न   ऐ स ी   द ु न ि य ा   म े ं   ज ह ा ँ   ह म े ं   क ई   अ न ् य   स म स ् य ा ए ं   ह ै ं   क ् य ा   ह म े ं   ए क   औ र   क ा र ण   क ी   ज ़ र ु र त   ह ै"
# Translation: "you can the the the the the the the the the the the the the is is is is is is is is is is is world is is is is is is is is is is that that <EOS>"
#
# Source: "इ स क ा   म त ल ब   य ह   न ह ी ं   ह ै   क ि   अ फ ग ा न ि स ् त ा न   स े   फ र ् क   न ह ी ं   प ड ़ त ा   ल े क ि न   व े ह   द ु न ि य ा   क े   द े श ो ं   म े ं   स े   ए क   ह ै   ज ि स क े   स ा थ   ह म े ं   स ं ल ग ् न   क ी   ज र ू र त   ह ै"
# Translation: "that mean that that that that that afghanistan that not that afghanistan but afghanistan but the world is afghanistan with the world but have a have a have a have a have a <EOS>"
#
# Source: "य ह   फ ् र े"
# Translation: "it <EOS>"
#
# Source: "ल ु क ा स"
# Translation: "lucas <EOS>"
#
# Source: "र ा ह ु ल   फ ् ल ा इ ट   स े   द ि ल ् ल ी   छ ो ड ़   क र   ज ा   र ह ा   ह ै"
# Translation: "rahul rahul is rahul rahul <EOS>"
#
# Source: "क ि स   आ ध ा र   प र   इ स   आ ध ा र   प र"
# Translation: "what the the the <EOS>"
#
# Source: "य ह   स च म ु च   श ा न द ा र   ह ै"
# Translation: "its is a <EOS>"
#
# Source: "स ं ख ् य ा   झ ू ठ   न ह ी ं   ह ै"
# Translation: "lie <EOS>"
#
# Source: "आ ओ   द े ख े ं   त ब   ह म न े   द ु न ि य ा   क ो   र ो क   द ि य ा   य ह   प ू र ् ण   य ू ए न   ग ण न ा   ह ै"
# Translation: "see how we have have the the the world have <EOS>"
#
# Source: "म े र ा   Y o s h i k a z u   क े   द ् व ा र ा   प ् र द र ् श न   क ि य ा"
# Translation: "my did my my <EOS>"
#
# Source: "व े   आ   र ह े   ह ै ं"
# Translation: "theyre coming <EOS>"
#
# Source: "ए क   स व ा ल   आ प   उ स े   ज ि त न ा   च ा ह े"
# Translation: "you you you you you you you you you <EOS>"
#
# Source: "ठ ी क   ह ै   ल ड ़ क ो ं"
# Translation: "all right boys <EOS>"
#
# Source: "क ् य ा   म ै ं"
# Translation: "what i i <EOS>"
#
# Source: "इ स क ा   म त ल ब   स ि र ् फ   स ा म ा न   ह ै   ठ ी क"
# Translation: "thats just right just fine right <EOS>"
#
# Source: "स ब स े   अ च ् छ ी   ब ा त   इ स क े   प ह ल े   न म ू न े   क ो   ब न ा न े   म े ं   स ि र ् फ   ड ा ल र   ख र ् च   ह ु ए"
# Translation: "first first first first first first first first first first first first first first first first first first first <EOS>"
#
# Source: "K K   ध न ् य व ा द"
# Translation: "thank you <EOS>"
#
# Source: "म ि ल क र   ख ़ ु श ी   ह ु ई   ल ड ़ क ो ं"
# Translation: "boys boys <EOS>"
#
# Source: "क ि   स र क ा र   क ी   न ई   ग द ् द ी   क े   ल ि ए"
# Translation: "thats what government for government <EOS>"
#
# Source: "य ह   न ह ी ं   ह ै"
# Translation: "its not <EOS>"
#
# Source: "र ण द े व   द े श द ् र ो ह ी   ब न   ग य ा   ह ै"
# Translation: "the is is is <EOS>"
#
# Source: "इ न   अ त ् य ं त   भ ि न ् न   क ् ष े त ् र ो ं   म े ं   ए क   स म ा न त ा   ह ै   ए प ि ज े न े ट ि क ् स"
# Translation: "in in a in in in <EOS>"
#
# Source: "ब ् र ा ग ा   क ौ न   ह ै"
# Translation: "whos who <EOS>"
#
# Source: "क ृ प य ा   म ु झ े   ब त ा ओ   त ु म   क ् य ो ं   क र   र ह े   ह ै ं   त ो   म े र े   ल ि ए   क ् य ा   म त ल ब"
# Translation: "please tell me why youre are for me for me for me <EOS>"
#
# Source: "उ न क े   प ा स   ल घ ु   अ र ् थ व ् य व स ् थ ा   ह ै"
# Translation: "they have have a a <EOS>"
#
# Source: "य ह   ब च ् च े   ह ा न ि क ा र क   औ र   स स ् त ी   म ो ट ा प ा   ब ढ ़ न े   व ा ल ी   च ी ज ़ े ं   ख ा त े   ह ै   ज ो   उ न क े   स म ु द ा य   म े ं   उ प ल ब ् ध   ह ै   औ र   ज ि न ् ह े ं   उ न क े   प र ि व ा र   ख र ी द न े   म े ं   स म र ् थ   ह ै ं"
# Translation: "this is a children is children and children and children and and <EOS>"
#
# Source: "औ र   य े   स े ब   स ा उ थ   अ फ ् र ी क ा   स े   य ह ा ँ   त क   आ य े   ह ै ं"
# Translation: "and this just here <EOS>"
#
# Source: "ब े ट ा"
# Translation: "son <EOS>"
#
# Source: "न म स ् क ा र   भ ा ई"
# Translation: "brother <EOS>"
#
# Source: "P A N T I N G"
# Translation: "<EOS>"
#
# Source: "ज ो   आ प   य ह ा ँ   द े ख त े   ह ै   य ह   स ु ं द र   ह ै   ल ु ई   व ि त ् त ो ं   क प   ट ् र ा फ ी"
# Translation: "so you you this beautiful beautiful <EOS>"
#
# Source: "औ र   व ह   म ु झ   प र   प र   र ख ा"
# Translation: "and she me on me <EOS>"
#
# Source: "म ै ं   स ि र ् फ ़   स े ऐ ट ल   म े ं   ब ै ठ ा   अ प न े   ब च ् च ो ं   क ो   ब ड ़ ा   न ह ी   क र   स क त ा   ए क   उ क ् छ म ध ् य म   व र ् ग ी य   प ड ़ ो स   म े ं   ब ै ठ े   औ र   इ स   ब ा त   क े   स ो च क र   अ च ् छ ा   म ह स ू स   क र ू ँ"
# Translation: "i cant feel the little girl in the piece of the piece of the piece of the and and and and and and and and and and and and and and and and and and and and <EOS>"
#
# Source: "म े र ा   म त ल ब   ह ै   क ि त न ा   क र   स क त े   ह ै ं"
# Translation: "i mean how do <EOS>"
#
# Source: "ए क   स ् क ी   झ ो ं प ड ़ ी"
# Translation: "the <EOS>"
#
# Source: "त ु म स े   प ् य ा र   क र त ा   ह ू ँ"
# Translation: "i love you <EOS>"
#
# Source: "अ ब   आ प   त स ् व ी र े ं   ख ी ं च े ग े ं"
# Translation: "now you now <EOS>"
#
# Source: "स ि क ं द र   त ु म ् ह े ं   आ श ी र ् व ा द"
# Translation: "alexander alexander <EOS>"
#
# Source: "म े र ी   प ो त ी   ह ै   क ि   म े र े   ल ि ए   द े   द ि य ा"
# Translation: "that is to my my <EOS>"
#
# Source: "प ि ं क ी"
# Translation: "<EOS>"
#
# Source: "न ह ी ं   म ै ं   श ा ं त   क ह न े   व ा ल ा   थ ा"
# Translation: "no i was gonna calm up <EOS>"
#
# Source: "ड ि य ा ब ् ल ो   स ् प ष ् ट   ह ो"
# Translation: "so clear clear <EOS>"
#
# Source: "अ फ ् र ि क ा   म े ं   द े श   ह ै ं"
# Translation: "country <EOS>"
#
# Source: "उ ह   उ ह"
# Translation: "uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh uh <EOS>"
#
# Source: "आ ग े   क ् य ा   ह ो ग ा"
# Translation: "what would you forward <EOS>"
#
# Source: "म ै ं   आ प क ो   अ प न े   ख ु द   क े   म ध ् य स ् त त ा   क े   अ न ु भ व   स े   ए क   क ि स ् स ा   स ु न ा त ा   ह ू ँ"
# Translation: "i i you you myself myself <EOS>"
#
# Source: "अ ब   व ह   र ॉ ब र ् ट   N k o m o   म ो र े ल   क र न े   ब ा ह र   अ न ु ब ं ध"
# Translation: "now he want to out to <EOS>"
#
# Source: "ह ा ँ   व े   क ् ल ो न   ब ड ़ ा   आ द म ी   व ा ल ा   क र   र ह े   ह ै ं"
# Translation: "yes they are gonna man <EOS>"
#
# Source: "क ् ल ि क   क ् ल ि क   आ व ा ज   इ स क े   ब ा र े म े   क ु छ   ध ् य ा न म े   आ य ा"
# Translation: "it clicks it immediately made it immediately <EOS>"
#
# Source: "म ै ं   आ प   स े   म ा ं ग   र ह ी   ह ू ँ   आ प क े   स ी म ि त   स ं स ा र   म े ं   क ् य ा   आ प   अ प न ा   म न   ख ो ल   स क त े   ह ै ं   क ् य ा   आ प   अ प न ा   द ि ल   ख ो ल   स क त े   ह ै ं"
# Translation: "i can you heart you your heart <EOS>"
#
# Source: "क ह ा न ि य ा ँ   ह म म े ं   प र ि व र ् त न   ल ा त ी   ह ै ं"
# Translation: "the is is <EOS>"
#
# Source: "म ा ह ौ ल   अ भ ी   भ ी   ख ड ़ ा   ह ै"
# Translation: "its is still <EOS>"
#
# Source: "अ र े   उ स े   म ं च   स े   उ त ा र ो"
# Translation: "hey hey him that hey <EOS>"
#
# Source: "औ र   स ी म स   क ु छ   क र न े   म े ं   स क ् ष म   ह ै   ज ो   ह म   म ा न व   ख ो ज ी   न ह ी ं   क र   स क त े   ज ो   इ स क े   फ ू ल न े   स े   प ह ल े   स ू ं घ   ल े त ा   ह ै"
# Translation: "and some other can to to to to to to to to to <EOS>"
#
# Source: "ल ू स ी   म ि र ै न ् ड ो   क ा"
# Translation: "lucy mirando <EOS>"
#
# Source: "म ै ं   य ह   न ह ी ं   क ह   र ह ा   ह ू ँ   व े   ट ू ट   र ह े   ह ै ं"
# Translation: "i am not saying that are not <EOS>"
#
# Source: "क ् य ो ं"
# Translation: "why <EOS>"
#
# Source: "म ै ं   इ त न ा   स ब   अ भ ी   त क   य ह   क र न े   क े   ल ि ए   इ स ् त े म ा ल   न ह ी ं   क र   र ह ा   ह ू ँ"
# Translation: "im am not use to use to <EOS>"
#
# Source: "ख ै र   ए क   क प ड ़ े   ध ो न े   आ द म ी   क े   ल ि ए"
# Translation: "well for guy guy <EOS>"
#
# Source: "त ो   म ै ं न े   य े   स ी ख ा   क ि"
# Translation: "so i learned learned <EOS>"
#
# Source: "अ भ ि व ा द न   म ै ं   प ् र ो ज े र ि य ा   क े   ब ा र े   म े ं   थ ो ड ़ ी   औ र   ज ा न क ा र ी   द े न ा   च ा ह त ा   ह ू ँ"
# Translation: "applause and i i to to about about about <EOS>"
#
# Source: "त ु म   उ स े   न ह ी ं   ब च ा   स क े"
# Translation: "you didnt have him save <EOS>"
#
# Source: "व े   व ा ल ा   अ ध ि क   ह ो   र ह े   ह ै ं   प ह ल े   क ी   त ु ल न ा   म े ं   स ं ग ठ ि त   अ ध ि क   अ न ु श ा स ि त   ह म ा र े   ज ै स े   अ ध ि क"
# Translation: "theyre are more than more compared to our cells <EOS>"
#
# Source: "ह ा ँ   त ु म   ल ो ग   ज य क ा र   क ी   ए क   अ स ल ी   अ च ् छ ा   क ा म   क र   र ह े   ह ै ं   य ह ा ँ   म े र े   द ो स ् त"
# Translation: "yes youre working here youre looking for my friend for mine for friends for friends <EOS>"
#
# Source: "प ह ल ा   ब ि ज ़ न स   आ य ड ि य ा"
# Translation: "the first <EOS>"
#
# Source: "न म स ् क ा र   अ ध ् य क ् ष   म ह ो द य"
# Translation: "hello mr president <EOS>"
#
# Source: "आ ज"
# Translation: "today <EOS>"
#
# Source: "म े र ा   स ं ग ठ न   म र ी न   औ र   न ा व ि क   म ज ब ू त   थ ा"
# Translation: "my was my the and <EOS>"
#
# Source: "म ा ँ   क ा   उ न क े   अ ं त ि म   च ा र   द ि न ो ं   म े ं   द े ख भ ा ल   क ै स े   क र े   इ स   म ा म ल े   म े ं   न र ् स ो ं   न े   ह म ा र ा   स ा थ   द ि य ा"
# Translation: "so how to their stress of four their children we to <EOS>"
#
# Source: "व ि क ि र ण उ त ् प र ि व र ् त न ो ं क ो   ज न ् म द ि य ा"
# Translation: "<EOS>"
#
# Source: "ज ब   व ह   उ ठ त ा   ह ै   त ो   ख ु श ि य ो ं   स े   भ र ा   ह ो त ा   ह ै"
# Translation: "when she she shes full of <EOS>"
#
# Source: "त ु म ् ह े ं   र ो क   ज ु आ"
# Translation: "you will get <EOS>"
#
# Source: "प र   म ै ं   त ु म ् ह े ं   य ह   न ह ी ं   क र न े   द े   स क त ा"
# Translation: "but i cant tell you that that <EOS>"
#
# Source: "क र ् ण   म ै ं   ह ा ल   ह ी   म े ं   स ो च   र ह ा   थ ा"
# Translation: "recently i recently was recently <EOS>"
#
# Source: "ब स   त ु म   व ह ा ँ   स े   ल ड ़ न े   क ि   म े ं   क ि य ा   थ ा   क ी   त र ह   च ल त े   ह ै ं   ल े क ि न   ध ी म ी   औ र   ए क   ब ह ु त   क म   h i t t i n"
# Translation: "you you you you you you you you you you you you you you you you you you you <EOS>"
#
# Source: "ज ब   ह म   ब ड ़ े   ह ो त े   त ो   ह म ा र े   श र ी र   ए क   अ ल ग   व ा त ा व र ण   म े ं   र ह त ा   ह ै   ज ब   इ न   फ ा क ् ट र ् स   क ी   ब ा त   आ त ी   ह ै"
# Translation: "when we we we we we we we we we we <EOS>"
#
# Source: "आ प   स ब   स ा म ा न   क ै स े   प त ा   च ल े ग ा"
# Translation: "how you you <EOS>"
#
# Source: "अ ग र   व ो   म द द   क र   स क त ा   ह ै   ल े क ि न   व ह   स ि र ् फ   उ स े   उ स   त र ह   न ह ी ं   द े ख   स क त ा"
# Translation: "but if he could help him but but but but but but help <EOS>"
#
# Source: "उ न ् ह े ं   ल े न ा   ब ं द   क र े"
# Translation: "shut off the shut <EOS>"
#
# Source: "श"
# Translation: "watch <EOS>"
#
# Source: "य ा   भ य ं क र"
# Translation: "or or <EOS>"
#
# Source: "ब स   क ा फ ़ ी   ह ु आ"
# Translation: "thats just <EOS>"
#
# Source: "म ै ं   न ह ी ं   ज ा न त ा   क ि   क ् य ा   क ह न ा   ह ै"
# Translation: "i dont what what what i is <EOS>"
#
# Source: "ह म ा र ा   ध न"
# Translation: "our wealth <EOS>"
#
# Source: "म ै ं न े   य े   स ब   ज ो ड ़ ा   थ ा   म ै ं   च ी ज ़ े ं   इ क ट ् ठ ी   क र त ा   थ ा   ख ़ ू ब   ज म   क े"
# Translation: "i all the to all the the the the <EOS>"
#
# Source: "औ र   इ न ् ह े ं   भ ी   ज ़ र ू र ी   उ त ् प ा द   औ र   स े व ा ए ँ   ज ै स े   क ि   प ा न ी   औ र   स ् व ा स ् थ स े व ा   य ा   आ व ा स   ख र ी द न ा   प ड त ा   ह ै   औ र   य े   क र ी ब   स े   ग ु न ा   ज ् य ा द ा   क ी म त   अ द ा   क र त े   ह ै   म ध ् य व र ् ग ी य   ल ो ग ो ं   क ी   अ प े क ् ष ा   क म   स े   क म   क र ा ँ च ी   औ र   न ै र ो ब ी   क े   ल ि य े   त ो   य े   आ ँ क ड ा   स च   ह ै"
# Translation: "and the will to to people people people people people people people people people people people people people people people <EOS>"
#
# Source: "न ह ी ं   त ु म   य ह ा ँ   न ह ी ं   र ु क   स क त ी   य ा   त ु म"
# Translation: "no you cant stay here <EOS>"
#
# Source: "व े   क ् य ा   ज र ू र त   ल ि स े   औ र   थ ि य ो   ख र ी द न े   क े   ल ि ए   प र ् य ा प ् त   प ै स ा   ह ै"
# Translation: "they they learn how they learn money for money <EOS>"
#
# Source: "म ै ं   स ा ल   प ह ल े   क ि य ा   ज ा न ा   च ा ह ि ए   क ् य ा   उ न क े   अ ं त ह ी न   ब ह स   क े   स ा थ   इ न   स ा ं स द ो ं"
# Translation: "i told them years ago ago to this year <EOS>"
#
# Source: "क ि स ी   G r e e l y   क ल   र ा त   क े   ब ा द   ए क   द ो   घ ं ट े   उ स े   ब ा ह र   ल े   ग य ा"
# Translation: "take out out out two hours to take him out out to the truck <EOS>"
#
# Source: "A l a i n   d e   B o t t o n   ह ा ँ   म ु झ े   ल ग त ा   ह ै   क ि   य ह   क े व ल   आ क स ् म ि क त ा   ह ै   ज ी त न ा   औ र   ह ा र न ा   ए क   प ् र क ् र ि य ा   ह ै   ज ि स   प र   म ै ं   प ् र भ ा व   ड ा ल न ा   च ा ह त ा   थ ा   क ् य ो ं क ि   आ ज क ल   ब ा त ो ं   क ो   ज ो र   ड ा ल क र   क ह न ा   ब ह ु त   ज र ु र ी   ह ै   स ब   क े   न ् य ा य   प र   औ र   न े त ा   ह म े श ा   न ् य ा य   क े   ब ा र े   म े ं   ब ा त   क र त े   ह ै"
# Translation: "laughter i i i i i i i the about and and and and and and and and and and and and and and and and and and and the the the the the the <EOS>"
#
# Source: "व ै स े   क प ड ़ े   स े   त ो   म ै ं   अ प न ा   ट ू व ् ह ी ल र   भ ी   स ा फ   न   क र ू ँ"
# Translation: "well i i i i i i <EOS>"
#
# Source: "स ा ल   प ह ल े   फ ॉ र ् म ि क स ्   न ा म क   ए क   प र र ् ग ह ी   स े न ा न े   ध र त ी   प े   ह म ल ा   ि क य ा"
# Translation: "years ago ago ago <EOS>"
#
# Source: "क ् य ा   त ु म"
# Translation: "what you you <EOS>"
#
# Source: "आ प   क र   र ह े   ह ै ं   आ प   प ा र ि त   न ह ी ं   स ा ह ब   क र   स क त े   ह ै ं"
# Translation: "youre are not leaving the <EOS>"
#
# Source: "य ह   स ् म ा र क ी य   थ ा   औ र   ल ग त ा   थ ा"
# Translation: "it was and <EOS>"
#
# Source: "ब च ् च ा   म र   च ु क ा   ह ै"
# Translation: "dead <EOS>"
#
# Source: "ख ु श ी   म ु झ े   म े र े   ल ा ज व ा ब   ब च ् च ो   स े   म ि ल त ी   ह ै"
# Translation: "tell me i i my my <EOS>"
#
# Source: "त ो   म ु झ े   ग ह र े   स म ु द ् र   अ न ् व े ष ण   क ा   क ी ड ़ ा   क ा ट   ह ी   ग य ा   थ ा"
# Translation: "so i was the the the the <EOS>"
#
# Source: "क ौ न   इ स   म ह ा न   स ा म ् र ा ज ् य   प र   र ा ज   क र े ं ग े"
# Translation: "who will this this <EOS>"
#
# Source: "ए क   ब ड ़ ा   प ् र ि य   भ ा ग   ग े ट ् स   फ ़ ा उ न ् ड े श न   म े ं   म े र े   क ा म   क ा   य ह   ह ै   क ि   म ु झ े   व ि क ा स श ी ल   द ु न ि य ा   म े ं   ज ा न े   क ा   म ौ क ा   म ि ल त ा   ह ै   औ र   म ै ं   य ह   अ क ् स र   क र त ी   ह ू ँ"
# Translation: "the the the of of the the the the the the the the the the the the the the the the the the <EOS>"
#
# Source: "व ी न स   स े   म ं ग ल   ग ् र ह   क े   ल ि ए   व े   स ि त ा र ो ं   क ी   आ व ा ज   ग ् र ह ो ं   क े   च ा र ो ं   ओ र   ए क   अ ं ग ू ठ ी   भ ा ग ो   क ह न ा   क ौ न   आ प   क े   ल ि ए   द े ख   र ह े   ह ै ं"
# Translation: "for the the of of of of of all different <EOS>"
#
# Source: "उ न ् ह ो ं न े   भ ु ग त ा न   न ह ी ं   क ि य ा"
# Translation: "they paid paid <EOS>"
#
# Source: "ह ं स ी   य े   स ब   ल ग   भ ग   ऐ स े   ह ु आ   थ ा"
# Translation: "laughter was was all laughter <EOS>"
#
# Source: "ल ो ह े   क ी   छ ड ़ े ं   इ क ट ् ठ ी   क र त ा   ह ू ँ   ज ि न क ा   उ प य ो ग   ग ु ल ा म ो ं   क ो   च ि ह ् न ि त   क र न े   क े   ल ि ए   ह ो त ा   थ ा"
# Translation: "i used to to to to to to to to to <EOS>"
#
# Source: "क ि स ी   क ो   य े   म ौ क ा   न ह ी ं   म ि ल त ा"
# Translation: "get get get any get to get get them <EOS>"
#
# Source: "व ो   अ क े ल ी   औ र त   ह ै"
# Translation: "she woman <EOS>"
#
# Source: "द ू र   ह ो   ज ा ओ"
# Translation: "get away <EOS>"
#
# Source: "य ह   ज ़ ि ं द ग ी   ब द ल   स क त ा   ह ै"
# Translation: "it changed is life <EOS>"
#
# Source: "म ै ं   य ह   द े ख न ा   च ा ह त ी   ह ू ँ"
# Translation: "i see that <EOS>"
#
# Source: "आ ग े   ब ढ ़ ो   आ द म ी   ख ि ल ा ओ"
# Translation: "go ahead <EOS>"
#
# Source: "स च ् च ा ई   य ह   ह ै   क ि   उ न क े   ल ि ए   व ह ा ं   ग य ा   थ ा   ज ब   त क"
# Translation: "this that truth that true until true when this <EOS>"
#
# Source: "अ भ ी   इ स क े   ल ि ए   स म य   ह ै"
# Translation: "for for for time for <EOS>"
#
# Source: "औ र   ह म   उ न क े   स ा थ   क ा म   क र क े   स म ् म ा न ि त   ह ै ं   औ र   अ ब   ह म   अ न ् य   द े श ो ं   म े ं   क ा म   क र   र ह े   ब ह ु त   स े   स ं ग ठ न ो ं   क े   स ा थ   म ि ल क र   उ न क ी   म द द   क र   र ह े   ह ै ं   त ा क ि   व े   भ ी   ऐ स ा   क र   स क े ं"
# Translation: "and so we were working with a other of individuals and other and to <EOS>"
#
# Source: "र ु प ए   क ा   न ो ट"
# Translation: "the of <EOS>"
#
# Source: "म ै ं   च ा ह त ी   थ ी   उ न क ी   त र ह   ए क   क ॉ ल े ज   क ी   ड ि ग ् र ी   इ स ल ि ए   म ै ं न े   अ प न े   प ि त ा   औ र   र ि श ् त े द ा र ो ं   स े   क ॉ ल े ज   भ े ज न े   क े   ल ि ए   झ ग ड ा   क ि य ा   औ र   य ह   क ा म   क ि य ा"
# Translation: "i wanted to work my degree of i wanted to go to the degree i i i i to to to to to to <EOS>"
#
# Source: "औ र   ह म ा र े   ल ि ए   ब ह ु त   म ह त ् व प ू र ् ण   थ ा   व ो   क ् ष ण   न ि र ् ध ा र ि त   क र न ा   ज ब   य ह   ग ि र े ग ा   क ् य ु ं क ि   अ ग र   ह म न े   इ स   त र ह   ब न ा य ा   क ि   य ह   प ल ट   ज ा ए   त ो   य ह   ख ु द   क ो   न ु क स ा न   प ह ु ँ च ा य े ग ा   औ र   अ ग र   य ह   ठ ी क   स े   न ह ी ं   ग ि र ा   त ो   य ह   व ो   न ि य त ि व ा द   प ै द ा   न ह ी ं   क र े ग ा   य ा   ज ा   क र   म द द   क र न े   क ी   इ च ् छ ा   क ा   भ ा व"
# Translation: "and when fact when our way to to to to to or or or or and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and and <EOS>"
#
# Source: "आ प   क ो   न ष ् ट   क र न े   क े   ल ि ए   ज न ् म े"
# Translation: "you will destroy to <EOS>"
#
# Source: "श ह र   न े   य ो ज न ा   ब न ा ई   ह ै   अ च ् छ े   य ा   ब ु र े   क े   ल ि ए   क र ो ड ़   व र ् ग   फ ी ट   ज ग ह   क ा   व ि क ा स   क र न े   क ी   ज ि स क े   आ स प ा स   द   ह ा ई   ल ा इ न   ए क   म ु द ् र ि क ा   ब न ा ए ग ी"
# Translation: "the is the the million in million the million million in million million city or million countries <EOS>"
#
# Source: "अ र े"
# Translation: "hey <EOS>"
#
# Source: "ब ू आ"
# Translation: "its <EOS>"
#
# Source: "व े   न े त ृ त ् व   म े ं   क ह ा ँ"
# Translation: "where will lead <EOS>"
#
# Source: "च ल ो   द े ख े   ल ड ़ क े"
# Translation: "come on <EOS>"
#
# Source: "ह ि न ् द ी   उ र ् द ू   उ प श ी र ् ष क   क ै प ् श न   क म ् प ् य ू ट र   अ न ू द ि त"
# Translation: "the training will be <EOS>"
#
# Source: "अ ब   स र क ा र   स े   स म ् ब ं ध ि त   ए क   ब ह ु त   म ह त ् व प ू र ् ण   ब ा त   य ह   ह ै   क ि   स र क ा र   औ र   र ा ज न ी त ि   स म ा न ा र ् थ ी   न ह ी ं   ह ै   व ह   भ ि न ् न   ह ै"
# Translation: "now government politics politics of government is politics is government is politics is is is is is is is is is is is is is is is is is is <EOS>"
#
# Source: "व ा द ा   क र ो   न ह ी ं   ब त ा ओ ग े"
# Translation: "promise <EOS>"
#
# Source: "न ह ी ं   क र न ा   ह ै"
# Translation: "no no <EOS>"
#
# Source: "च ल े ं"
# Translation: "go <EOS>"
#
# Source: "औ र   क ु छ   प र ो प क ा र ी   क ा र ् य क र ् त ा   भ ी   ह ै ं   ज ो   इ स े   क र ु ण ा म य   श ् र म   क ह त े   ह ै ं"
# Translation: "and some of who are like this <EOS>"
#
# Source: "च ल ो   ऊ प र   च ल त े   ह ै ं"
# Translation: "lets go up <EOS>"
#
# Source: "औ र अ ध ि क आ प   य ह   उ च ् च   व ो ल ् ट े ज   क ा   च य न   क र े ं"
# Translation: "this high the high high <EOS>"
#
# Source: "म ु झ े   क ा र   स े   छ   ब ा र   ट क ् क र   ल ग ी   ह ै"
# Translation: "i i the time <EOS>"
#
# Source: "क ु छ   म त   ल ो   च ल ो   क ् य ा"
# Translation: "dont get some to <EOS>"
#
# Source: "इ न   न ए   आ ँ क ड ़ ो ं   क े   स ा थ   ए क   म ह ि ल ा   ह ो न े   क ा   क ् य ा   अ र ् थ   ह ो त ा   ह ै"
# Translation: "women to a women to women to the <EOS>"
#
# Source: "ए क   ल ड ़ क ा   ड ू ब   र ह ा   ह ै"
# Translation: "a guy a <EOS>"
#
# Source: "य ह   स म य   ल े त ा   ह ै"
# Translation: "its time time <EOS>"
#
# Source: "व ह   ब च प न   स े   ह ी   क ा फ ी   ब ी म ा र   र ह त ा   ह ै"
# Translation: "she lived of very sick <EOS>"
#
# Source: "क ् य ो ं क ि   अ न ् त ः ग त ि   म े ं   ज ब   ह म े ं   स ु ख ी   ब ि न ा   ख म ी र   क ी   र ो ट ी   ख ा न ी   ह ो त ी   ह ै   र ब ् ब ी   ब त ा त े   ह ै ं   क ि   क ् य ा   फ र ् क   ह ै   उ स   ल ो ई   म े ं   ज ि स स े   र ो ट ी ख म ी र   व ा ल ी   ब न त ी   ह ै   औ र   उ स   ल ो ई   म े ं   ज ि स स े   स ु ख ी   र ो ट ी ब ि न ा   ख म ी र   व ा ल ी   ब न त ी   ह ै   म त ् ज ़ ा"
# Translation: "because when we we we we we we we we we we we we we <EOS>"
#
# Source: "क ो ई   ए क   व ा य र   ह ट ा   द े न ा   ज ि स स े   व ि स ् फ ो ट   न   ह ो"
# Translation: "no one one one one one <EOS>"
#
# Source: "म े र ा   म त ल ब   ह ै   व ह   त ु म ् ह े ं   फ ि र   स े   ह ु आ"
# Translation: "i mean you mean again <EOS>"
#
# Source: "ह म   अ क ् स र   उ स   प र   त ब   ध ् य ा न   द े त े ं   ह ै ं   ज ब   उ स क ी   द श ा   म े ं   क ु छ   ह ल च ल   ह ो   ज ै स े   ए क   द ु र ् ग न ् ध   य ा   क ु छ   प ् र त ् य क ् ष   ज ै स े   ध ु आ ँ   य ा   ध ु ं द"
# Translation: "we often like in a a a a a a a a a a a or or or or or or <EOS>"
#
# Source: "म े र े   आ र ो प   क े   ब ा द   म ै ं   आ प क ी   य ा द द ा श ् त   त ा ज ़ ा   क र   द ू ं   आ प क ो   ज ़ र ा   भ ी   श र ् म   न ह ी ं   ह ै"
# Translation: "i i i i have your son on on the <EOS>"
#
# Source: "T h e   m a u r e s q u e"
# Translation: "the <EOS>"
#
# Source: "त ु म   ठ ी क   ह ो"
# Translation: "youre okay <EOS>"
#
# Source: "र ा इ फ ल   श ॉ ट   च ि ल ् ल ा त ी"
# Translation: "screams <EOS>"
#
# Source: "र ् ज न   क ी   आ व ा ज   द ै व ी   ह स ् त क ् ष े प   य ा   क ् र ो ध   क ा   स ं क े त   ह ो   स क त ा   ह ै"
# Translation: "the the a a a a a a <EOS>"
#
# Source: "उ स क े   ब ा द   अ ग ल े   प ा च   स ा ल क ी   स ा र ् व ज न ि क   म ृ त ् य ु   न ो ं द   ज ा न ी   उ न म े स े   क ि त न ो क ी   म ृ त ् य ु   ह ू ँ ई"
# Translation: "next next next next next next next next next next next next next next next next next next next next next next next next next next next next next next next next next next next next next next next next next years next next next next next next years after <EOS>"
#
# Source: "ब स   ए क   ह ं स ी   ह ो   र ह ी   ह ै"
# Translation: "just have a laugh <EOS>"
#
# Source: "म ु झ े   न ह ी ं   ल ग त ा   क ि   य े   अ ं त र ् व ि ध ा   ब ह स व ि म र ् ष   अ प न े   आ प   ह ो   ज ा य े ग ा   इ स क े   ल ि य े   प ् र य त ् न   क र न ा   ह ो ग ा"
# Translation: "i dont think you will be will be you you <EOS>"
#
# Source: "आ प   व े   ब े ह त र ी न   क ो र ् स   ल े क र   उ न ् ह े ं   उ प ल ब ् ध   क र ा   स क त े   ह ै ं   त ा क ि   क ो ई   ब च ् च ा   ज ा   स क े   औ र   व ह   क ो र ् स   द े ख   स क े   उ स स े   स ी ख   स क े"
# Translation: "they can can can them and and and and and and and and and and <EOS>"
#
# Source: "म ु झ े   ड र   ह ै   क ि   अ ग र   म ै ं   उ स े   क र न े   क े   ल ि ए   ब ा त   क र त े   ह ै ं   म ै ं   प ् य ा र   म े ं   ग ि र   ज ा ए ग ी   ह ू ँ"
# Translation: "i i i i i i i i i <EOS>"
#
# Source: "न ह ी ं   न ह ी ं   न ह ी ं"
# Translation: "no no <EOS>"
#
# Source: "ख र ी द ा र ी   क र त े   र ह ि ए"
# Translation: "sorry <EOS>"
#
# Source: "द क ् ष ि ण   क े   य ु द ् ध   म े ं   ए क   व ह   ह ै"
# Translation: "at a war war war war <EOS>"
#
# Source: "ल े क ि न   व ो   य ू र ो प   म े ं   अ म े र ि क ा   स े   ज ़ ् य ा द ा   ब ड ़ ी   स म स ् य ा   ह ै"
# Translation: "but europe is europe is europe <EOS>"
#
# Source: "म ग र   आ प   क ह े ं ग े   क ि   श ो ध   क े   ब ा र े   म े ं   म े र ी   क ् य ा   र ा य   ह ै"
# Translation: "but you you you you you you you you you you <EOS>"
#
# Source: "आ स ा न   प ु न ः   ल ो ड   क े   ल ि ए   फ ् ल ै ट   m a c w e l l"
# Translation: "for for to <EOS>"
#
# Source: "त ु म   अ प न े   ब ा र े   म े ं   ब ा त   क र ो"
# Translation: "do you talk about <EOS>"
#
# Source: "प क ड ़ ो   उ स े"
# Translation: "hold him hold him <EOS>"
#
# Source: "ड ् य ू ट ी   क े   ल ि ए   र ि प ो र ् ट ि ं ग   स ा र ् ज े ं ट   म े ज र"
# Translation: "for for for for for for <EOS>"
#
# Source: "स भ ी   ज ी व न   प ् र त ि क ् र ि य ा ओ ं   प ा न ी   म े ं   ह ो त ी   ह ै ं"
# Translation: "all of all all <EOS>"
#
# Source: "त ु म   च ल े   ज ा ओ"
# Translation: "you go <EOS>"
#
# Source: "ल े क ि न   आ प   म े ं   स े   क ु छ   ल ो ग ो   य ह   ए ह स ा स   न ह ी ं   ह ो ग ा   क ी   म े ं   य ह ा ँ   आ न े   क े   ल ि ए   क ि त न ी   द ू र   स े   आ य ा   ह ु"
# Translation: "but you you you you you you you you you you you you you you <EOS>"
#
# Source: "म ै ं   इ स े   स ि र ् फ   उ स क े   भ ल े   क े   स ा थ   न ह ी ं   क र   स क त े"
# Translation: "i cant get with her with him <EOS>"
#
# Source: "ध ् य ा न   द े ं   स भ ी   ज ो न   त ी न   व े ल ् ड र"
# Translation: "so to attention to <EOS>"
#
# Source: "व ि श ् व व ि द ् य ा ल य   ज ह ा ँ   स े   उ स न े   स ् न ा त क ो त ् त र   उ प ा ध ि   ल ी   थ ी   उ स न े   व ह ा ँ   प ढ ा न े   क ा   प ् र स ् त ा व   द ि य ा   थ ा   ज ि स क ा   अ र ् थ   ह ै   न ा   क े व ल   व े त न   ब ल ् क ि   औ र   भ ी   फ ा य द े   ज ो   प ह ल ी   ब ा र   ह ु आ   थ ा"
# Translation: "this was this camp this camp over the surface there was a honor of the gave to the a a a and and and <EOS>"
#
# Source: "ख ा न े   क ी   द ु क ा न"
# Translation: "break up the shop <EOS>"
#
# Source: "म े र े   ए क   अ म र ी क ी   ग ो र ी   औ र त   ह ो न े   क े   न ा त े   म े र े   प ा स   ब ह ु त   स े   व ि श े ष ा ध ि क ा र   ह ै ं"
# Translation: "one of american of of <EOS>"
#
# Source: "औ र   घ ा ट ी   क े   क ि न ा र े   क ि न ा र े   आ ग े   ब ढ ़ े ं"
# Translation: "and the the the <EOS>"
#
# Source: "औ र   ह ा ँ   ह म न े   अ ध ि क   च य न ा त ् म क   द व ा ए ं   व ि क स ि त   क ी   ह ै ं   ल े क ि न   उ न ् ह े ं   ट ् य ू म र   म े ं   ल े   ज ा न े   क ी   अ भ ी   भ ी   ए क   च ु न ौ त ी   ह ै   औ र   व े   अ न ् य   अ ं ग ो ं   म े ं   भ ी   स ं च ि त   ह ो   ज ा त ी   ह ै ं   य ा   म ू त ् र   म े ं   ब ह   ज ा त ी   ह ै ं   ज ो   ब ि ल ् क ु ल   ब र ् ब ा द ी   ह ै"
# Translation: "and now we have a that that that that that that that that have and those and that that that that that <EOS>"
#
# Source: "म ै ग ी   प र   क ् य ा   ह ो   र ह ा   ह ै"
# Translation: "what are you on <EOS>"
#
# Source: "आ प   इ स   ए क   क ा   अ प न ा   र ा स ् त ा   ब ा ह र   च ी ख   न ह ी ं   क र   स क त ा"
# Translation: "you cant be out of your and <EOS>"
#
# Source: "म ै ं   ए ल े न   म ह स ू स   ब े ह त र   उ म ् म ी द   ह ै"
# Translation: "i just feel better <EOS>"
#
# Source: "न   स ि र ् फ   म ु झ े   द े ख त े   ह ै ं   ल े क ि न   य ह   भ ी   म े र े   ल ि ए   ब ा त   क र त े   ह ै ं"
# Translation: "but just dont see but but me but <EOS>"
#
# Source: "ल े क ि न   ड े न म ा र ् क   म े ं   ह म े ं   अ न ु म त ि   ह ै"
# Translation: "but we is is <EOS>"
#
# Source: "उ स न े   ड ै न ी   क ा   ग ल ा   घ ो ं ट न े   क ी   क ो श ि श   क ी"
# Translation: "she tried the the <EOS>"
#
# Source: "फ ि र   म ै ं न े   ब च प न   म े ं   अ प न े   न ा श ् त े   क ी   ट े ब ल   स े   ज ै म   क ी   ब ो त ल   ग ा य ब   ह ो त े   द े ख ी   उ स क े   ब ा द   म ा र ज ा र ि न   भ ी   ग ा य ब   ह ो   ग य ा   फ ि र   ब ् र ै ड   ब ह ु त   म ह ं ग ी   ह ो   ग ई   औ र   द ू ध   र ा श न   स े   म ि ल न े   ल ग ा"
# Translation: "after then i started to and and and and and and and <EOS>"
#
# Source: "व ि भ ि न ् न   भ ा ग ो ं   म े ं   क ई   द र ् ज न   ऐ स े   स र ् व े क ् ष ण   द ु न ि य ा   क ी   औ र   स भ ी   म ा म ल ो ं   म े ं   ए क   क ो   छ ो ड ़ क र   ज ह ा ं   व ा स ् त व   म े ं   ए क   स म ू ह   क ो   क म   क र क े   आ ं क ा   व ् य ा प ा र   क े   ल ि ए   स क ल   घ र े ल ू   उ त ् प ा द   क े   अ न ु प ा त   ल ो ग ो ं   क ो   इ स   प ् र व ृ त ् त ि   अ ध ि क   आ क ल न   क ी   ओ र   औ र   इ स ल ि ए   म ै ं न े   स ो च ा   ए क   न ा म   द े   औ र   व ह   ह ै   ग ह र े   न ी ल े   र ं ग   क ी   स ल ा ख ो ं   क े   ब ी च   g l o b a l o n e y   अ ं त र   क े   र ू प   म े ं   औ र   ह ल ् क े   भ ू र े   र ं ग   स ल ा ख ो ं"
# Translation: "the set of of of of of of of of of and and and and and and and and and and and and and and and and and and and and and <EOS>"
#
# Source: "र क ् त   क ् य ो ं   म ह त ् व प ू र ् ण   ह ै"
# Translation: "why is important for <EOS>"
#
# Source: "इ स   स ं द र ् भ   म े ं   अ म े र ि क ी   स र क ा र   भ ी   इ न   ट ा इ प फ े स ो ं   क ा   प ् र य ो ग   क र   र ह ी   थ ी   द ् व ि त ी य   व ि श ् व य ु द ् ध   क े   ब ा द   न क ् श े   औ र   प ् र ो ज े क ् ट ् स   म े ं   फ ् य ू च ु र ा   क ा   प ् र य ो ग   क ि य ा   ग य ा"
# Translation: "this this that series of series software that data that software and data <EOS>"
#
# Source: "उ स न े   ब ो ल ा   ऐ स ा   म त   क र"
# Translation: "dont not the <EOS>"
#
# Source: "औ र   म ै ं   म ि न ट   क ी   आ व श ् य क त ा   ह ो ग ी"
# Translation: "and ill will be quick <EOS>"
#
# Source: "ज ह ा ज   प र   द ु ख ी   स ् क ् र ै प   क र न े   व ा ल ी   क ो ई   भ ी   न ा व   न ह ी ं   ह ै   ज ो   क ि   क ो   ज ी त त ा   ह ै"
# Translation: "the is is is is is is <EOS>"
#
# Source: "म ै ं न े   उ स स े   प ू छ ा   क ि   क ् य ा   व ो   म े र े   स ा थ   क भ ी   भ ी   र ो म ा ं ट ि क   ड े ट   क े   ल ि ए   आ न ा   च ा ह े ग ी   औ र   उ स न े   क ह ा   न ह ी ं"
# Translation: "i asked asked asked asked asked asked asked asked asked asked asked asked asked what i asked his life for never asked me to the never asked me to the never said well it was never my mind <EOS>"
#
# Source: "त ु म   य ह ा ं   ए क द म   ठ ी क   ह ो"
# Translation: "you you you okay you <EOS>"
#
# Source: "अ ब   त क   इ न   ल ो ग ो   क े   प ा स   ब ह ु त   ह ी   अ प ् र ि य   व ि क ल ् प   र ह ा   ह ै"
# Translation: "now these guys have a lot of these <EOS>"
#
# Source: "य ह   स ि ल ् व र े ट   द ् व ा र ा   ह ै"
# Translation: "this is <EOS>"
#
# Source: "म ै ं   भ ी   ए क   h o r o l o g i s t   ह ै"
# Translation: "i i an entirely <EOS>"
#
# Source: "म ख ौ ल   उ ड ़ ा त े   ह ा ँ   स ह ी   ह ै"
# Translation: "scoffs right <EOS>"
#
# Source: "म ा ल क ि न   न े   उ स े   क ा ट   द ि य ा"
# Translation: "the missus cut <EOS>"
#
# Source: "व े   क ् य ा   क र   र ह े   ह ै ं"
# Translation: "what are they doing <EOS>"
#
# Source: "ऐ स ा   ल ग त ा   ह ै   क ि   य ह   ए क   र ो ल र   स े   भ ी   ज ़ ् य ा द ा   भ ा र ी   ह ै"
# Translation: "its that that that that that than that than <EOS>"
#
# Source: "प ् व ा इ ं ट   ल ि य ा"
# Translation: "hey took <EOS>"
#
# Source: "ह म   म े ं   स ं ल ग ् न   न ह ी ं   ह ै   अ व ै ध   ग त ि व ि ध ि य ो ं   छ ो ड ़   द ो"
# Translation: "we leave two <EOS>"
#
# Source: "ल ो ग ो ं   न े   स भ ी   क ु छ   द े ख ा   ह ै   अ ं त र ि क ् ष   म े ं   व ि श ा ल   छ ा त ा   ब न ा न े   स े   स ा ग र   म े ं   ध ् व न ी   प ै द ा   क र न े व ा ल े   ब ु ल ब ु ल ा   प ा न ी   त क"
# Translation: "the seen the seen water more seen anything of water more than the last century <EOS>"
#
# Source: "ह र   क ो ई   इ स े   क र   स क त ा   ह ै   ब स   थ ो ड ़ ा   अ भ ् य ा स   च ा ह ि ए   ल े क ि न   आ ज   क े   ल ि ए   य ह   ए प ि न े फ ् र ी न   ह ै"
# Translation: "but but it but it but it but it but it <EOS>"
#
# Source: "म े र ा   स ब स े   प स ं द ी द ा   प ह ा ड ़ ा   ह ै   क ा"
# Translation: "the favorite favorite favorite favorite of favorite <EOS>"
#
# Source: "ह े ल ो"
# Translation: "hello <EOS>"
#
# Source: "अ प न े   प त ो ं   क ो   स ा म ा न ् य   ब न ा न ा   श ु र ु   क र े ं"
# Translation: "wait your your <EOS>"
#
# Source: ""
# Translation: " <EOS>"
#
# Source: "व ह   क ह त ी   ह ै ं   क ि   ज ॉ न   A r r y n   ह त ् य ा   क र   द ी   थ ी"
# Translation: "she was that of of <EOS>"
#
# Source: "क ् य ो ं क ि   स ा ं ख ् य ि क ी य   र ू प   स े   ज ो   छ ा त ् र   ब े घ र   ह ै ं   य ा   ज ि न क े   प ा स   अ स ् थ ि र   र ह न े   क ी   स ् थ ि त ि   ह ै   व े   श ा य द   ह ी   क भ ी   ह ा ई   स ् क ू ल   प ू र ा   क र त े   ह ै ं"
# Translation: "because because of of that that that that that that that that that that that that <EOS>"
#
# Source: "त ो   ह म   क ु छ   ड ा इ ट   क ो क   क ा   आ द े श   द े न ा   च ा ह ि ए"
# Translation: "so we should give some of of <EOS>"
#
# Source: "ड ॉ ग   न े   म ु झ े   य ह   प त ा   च ल त ा   ह ै"
# Translation: "i know i i <EOS>"
#
# Source: "श ा य द   य ह   भ ी   म न ु ष ् य ो ं   ल े क ि न   य ी श ु"
# Translation: "but perhaps humans too but humans <EOS>"
#
# Source: "त ु म ल ो ग   स ज ा य ा फ ् त ा   द ो ष ी   ह ो"
# Translation: "yes <EOS>"
#
# Source: "आ प क ो   ग ल त फ ़ ह म ी   ह ु य ी   ह ै"
# Translation: "you have you <EOS>"
#
# Source: "स म ा च ा र ो ं   म े ं   उ स   s a m a y   य े ह ी   द ि ख ा य ा   ग य ा   क ी   प त ् थ र   म ो ल ो त ो व   ब ा र ू द   औ र   ज ल त े   ह ु ए   प ा इ ए   ह ी   स ि र ् फ   ग त ि व ि ध ि य ा   थ ी   इ न ् त ि फ ा द ा   क े   स म य l"
# Translation: "that was that that that that in in in <EOS>"
#
# Source: "म ै ं   न ह ी ं   ज ा न त ी   ह ू ं"
# Translation: "i dont know <EOS>"
#
# Source: "अ भ ी   ओ क ् ज ा   स े   फ ़ ो न   प र   ब ा त   क र ा ओ"
# Translation: "now i right now <EOS>"
#
# Source: "र ा त   म े ं   ज म ा   स र"
# Translation: "night to night night <EOS>"
#
# Source: "म े र ा   म त ल ब   ह ै   य ह ा ँ   ए क   प ् र म ु ख   ज ल व ा य ु   स ं क ट   ज ा ह ि र   ह ै   औ र   म ु झ े   ल ग त ा   ह ै   क ि   अ ग र   ल ो ग ो ं   क ो   य ह   व ि श ् व ा स   न ह ी ं   क र त े   ह ै ं   उ न ् ह े ं   औ र   अ ध ि क   म ि ल न ा   च ा ह ि ए"
# Translation: "i believe believe believe believe believe believe there was a believe believe believe that believe that believe that believe that believe that believe that believe that believe that believe and the needed to believe that the needed to believe to the needed to be needed to the needed to the needed to the needed to the <EOS>"
#
# Source: "त ु म ् ह ा र े   र ं ग   ल ग   ग य ा   ह ै"
# Translation: "your color is <EOS>"
#
# Source: "व ह   स ै र   ऐ स े   क र त ा   म ा न ो   प ा र ् क   म े ं   ह ो   ब ि न ा   प र व ा ह   य ा   द ु न ि य ा   क ी   च ि ं त ा   क ि ए"
# Translation: "he the the without the the world in the <EOS>"
#
# Source: "क म ी न ो ं"
# Translation: "the you <EOS>"
#
# Source: "औ र   य ह ा ं   त क   u b u b क ि   म ा त ा प ि त ा   भ ी   च ि त ् र ो ं   म े ं   र ं ग   क ी   अ न ु प स ् थ ि त ि   क ो   द े ख क र   स म झ   स क त े   ह ै ं   क ी   उ न क े   ब च ् च े   उ न ् ह े ं   क ् य ा   क ह   र ह े   ह ै ं   उ त न ा   ह ी   म ह त ् व प ू र ् ण   ह ै   ज ि त न ा   व े   न ह ी ं   क ह त े   ह ै ं"
# Translation: "and even their parents can even their parents of even in their parents <EOS>"
#
# Source: "त ो   ब ज ा य   उ न क ा   इ ं त ज ़ ा र   क र न े   क े   म ै ं न े   व ह   अ प न ा   ख ु द   क ा   ब न ा य ा   स ि र ् फ ़   ए क   क ा ग ज ़   क ो   ल े क र"
# Translation: "so i i i i a a a a a <EOS>"
#
# Source: "व ् य ा प ा र   क ै स ा   ह ै"
# Translation: "hows business <EOS>"
#
# Source: "त ा ल ि य ा ँ   व ह   व ा स ् त व   म े ं   त ा र ी फ ़   क े   क ा ब ि ल   ह ै   क ् य ो ं क ि   म ु झ े   न ह ी ं   ल ग त ा   व ह   प ि छ ल े   त ी न   म ह ी न ो ं   म े ं   ज ् य ा द ा   स ो य ा   ह ै"
# Translation: "applause shes three months since because three months i three things <EOS>"
#
# Source: "व ह   र ा न ी   ह म   च ु न ा   ह ै"
# Translation: "she chose the queen <EOS>"
#
# Source: "त ो   च ी ज े ं   ज ै स े   क ी   न व ज ा त   श ि श ु   द े ख भ ा ल   ग ह न   द े ख भ ा ल   श ल ् य   च ि क ि त ् स ा   औ र   इ म े ज ि ं ग   अ भ ी   भ ी   अ स ् प त ा ल   म े ं   र ह े ं ग े   म े र ा   म ा न न ा   ह ै   क म   स े   क म   न ि क ट   भ व ि ष ् य   क े   ल ि ए"
# Translation: "so for the like that hospital for hospital and the hospital and the hospital and my hospital and my hospital and my hospital and the hospital and the and and and and and and and and <EOS>"
#
# Source: "उ न ् ह े ं   य ह   स ब   द े ख न े स म झ न े   म े ं   थ ो ड ़ ा   स म य   ज ़ र ू र   ल ग ा"
# Translation: "they all time time time in time <EOS>"
#
# Source: "म ै ं   ब ह ु त   श र ् म ि ं द ा   ह ू ँ"
# Translation: "im am <EOS>"
#
# Source: "इ स स े   भ ी   ब ड ़ ी   ह ै"
# Translation: "even it is even <EOS>"
#
# Source: "य ा क ू ब   क ृ प य ा   ज ा ओ"
# Translation: "jacob jacob jacob jacob please jacob jacob jacob jacob jacob jacob jacob jacob jacob jacob jacob jacob jacob jacob jacob jacob jacob jacob jacob jacob <EOS>"
#
# Source: "म ु झ े   ल ग त ा   ह ै"
# Translation: "i think i <EOS>"
#
# Source: "इ न   त त ् व ो ं   क ो   स म झ   क र   ह म न े   ए क   म ि श ् र ण   त ै य ा र   क ि य ा   ह ै   ज ो   श र ी र   स े   प ै द ा   ह ो न े   व ा ल ी   व ि भ ि न ् न   च ी ज ़ ो ं   क ा"
# Translation: "these guys have a body those who have a body different body <EOS>"
#
# Source: "क ौ न   प र ि स र   म े ं   प ् र व े श   क ि य ा"
# Translation: "joe <EOS>"
#
# Source: "ओ ह   भ ग व ा न"
# Translation: "oh oh god <EOS>"
#
# Source: "म ै ं   य ह ा ँ   म े ं   ज ा न क ा र ी   म ि ल ी   ह ै"
# Translation: "i have in right here <EOS>"
#
# Source: "य े   उ त न ी   ब ड ़ ी   न ह ी ं   ह ै   य ा   उ त न ी   म ज ब ू त   न ह ी ं   ह ै   य ा   उ त न ी   स ् थ ा य ी   न ह ी ं   ह ै   क ि   व ि श ् व   क ी   ब ड ़ ी   स म स ् य ा ओ ं   क े   ल ि ए   स म ा ध ा न ो ं   क ो   स ं च ा ल ि त   क र   प ा ए   क ् य ू ँ क ि   य ह   ए क   त र ह   स े   ल ा ग त   ह ै"
# Translation: "this not than this than or or or or or or or <EOS>"
#
# Source: "C a r l i s l e   प ् र श ि क ् ष ण   द े ग ा   च ो ट   क ी   ज र ू र त   ह ै"
# Translation: "training training like the training <EOS>"
#
# Source: "क े व ल   ई श ् व र   स े"
# Translation: "god <EOS>"
#
# Source: "द ् व ा र ा   ख ड ़ े   क र न े   क े   ल ि ए   म ि स ा इ ल ो ं   आ ग"
# Translation: "by by by the <EOS>"
#
# Source: "ल ू ट   व ि ज ् ञ ा न   औ र   ध र ् म   क े   ब ी च   क ी   र े ख ा   त ो   उ न   ल ो ग ो ं   ध र ् म   क ा   व ि ज ् ञ ा न   स म झ   स क त े   ह ै ं"
# Translation: "so religion can and science and science and science and science <EOS>"
#
# Source: "औ र   ब च ् च े   ब ह ु त   क ् र ू र   ह ो   स क त े   ह ै ं"
# Translation: "and kids can kids can kids <EOS>"
#
# Source: "त ो   ह म   द े ख   र ह े   ह ै ं   इ स   उ प ल ब ् ध त ा   म े ं   व ृ ध ् द ि   म ो ब ा ई ल   स ा ध न ो ं   क े   फ ै ल ा व   स े   ब ढ ़   र ह ी   ह ै ं   व ि श ् व   म े ं   स भ ी   स ा म ा ज ि क   स ् त र   प र"
# Translation: "so were all watching the world the the all the world the the world all that world the world <EOS>"
#
# Source: "म े र ी   ब ं द ू क"
# Translation: "gun <EOS>"
#
# Source: "ब ह ु त   स े   ल ो ग ो   क ो   ल ग त ा   ह ै   क ि   अ व ध ा न   स ि र ् फ   ध ् य ा न   क े ं द ् र ि त   क र न े   क े   ब ा र े   म े ं   ह ै   अ व ध ा न   क ा   स म ् ब न ् ध   इ स स े   भ ी   ह ै   क ि   ह म ा र ा   म स ् त ि ष ् क   क ् य ा   फ ़ ि ल ् ट र   क र न े   क ी   क ो श ि श   क र   र ह ा   ह ै   l"
# Translation: "we think that a a a a trying to focus attention just <EOS>"
#
# Source: "स ड ़ क ो ं   प र   व े   उ स े   अ ल   ड ि य ा ब ् ल ो   क ह त े   ह ै ं"
# Translation: "they they they they they they they <EOS>"
#
# Source: "ह म   आ प क ो   ल ड ़ ा ई   म े ं   व ा प स   म ि ल   ज ा ए ग ा   ख ो ख ल े   ख त ् म   ज ो   क ु छ   भ ी   व ह   श ु र ू   क र   द ि य ा   इ स स े   प ह ल े   क ि"
# Translation: "we just give you to first thing <EOS>"
#
# Source: "C A S E   त ु म   म े र े   स ा थ   आ   र ह े   ह ो"
# Translation: "with my youre gonna <EOS>"
#
# Source: "प र   व ा क ई   अ स ल   ब ा त   त ो   व ह ी   ह ै"
# Translation: "but so is is is really really the that <EOS>"
#
# Source: "श े र ि फ"
# Translation: "sheriff <EOS>"
#
# Source: "ब स   इ त न ा   ह ी"
# Translation: "thats it <EOS>"
#
# Source: "य ह   क ि स ी   औ र   र ू प ा ं त र   ज ै स ा   न ह ी   थ ा"
# Translation: "it wasnt like that <EOS>"
#
# Source: "स ब स े   प ह ल ा   ख ़ ा म ो श ी"
# Translation: "first first first first first first first <EOS>"
#
# Source: "ए क   छ ो ट ा   स ा   अ ध ि क   द य ा   द ि ख ा न े   क े   ल ि ए   म ै ं   क ी   त र ह   उ स   प र   भ र ो स ा   थ ा"
# Translation: "i little little bit more likely i me like that little more than me <EOS>"
#
# Source: "र ि ब क ा   स ु झ ा व   द ि य ा   म ै ं   उ न ् ह े ं   स ु न त े   ह ै ं"
# Translation: "i i gave them to to have to <EOS>"
#
# Source: "व ह   द े ख त े   ह ी   श म ा ं   ब न   ग य ा   ए क   स ु ब ह   स म ु द ् र   म े ं   ए क   स ं क े त   अ प न े   प ि त ा   औ र   द ा द ा   क ी   त र ह   उ स क े   स ा म न े"
# Translation: "she became his father and his father and his father and his father and his father and his father <EOS>"
#
# Source: "प ् र त ् य े क   व र ् ष   ह म   क ु छ   व ् य क ् त ि य ो ं   क ो   च ु न त े   ह ै   औ र   श ह र ो ं   क े   प ् र श ा स न   म े ं   उ न ् ह े ं   क ा म   क र ा त े   ह ै ं"
# Translation: "some of of years old years old and the of of of of of of of of of of of of of of <EOS>"
#
# Source: "य ह ी   व ज ह   ह ै   क ि   म ै ं   प ै स े   क े   प ी छ े   न ह ी ं   भ ा ग   र ह ा"
# Translation: "thats not the the the <EOS>"
#
# Source: "औ र   अ ग ल े   स ा ल   व ो   द े व ी   फ ि र   आ य े ग ी"
# Translation: "and then next years for <EOS>"
#
# Source: "आ प क ो   ल ग त ा   ह ै   क ि   ट ् र ि ग र   ख ी ं च न े   क े   ल ि ए   त ै य ा र   ह ै ं   ज ब   त क   म ै ं   त ु म   क ् य ा   ब त ा   औ र   स ि र   क ो   ए क   ग ो ल ी   ड ा ल   क ि   न ौ   च क ् क ी   ज ् य ा द ा   म द द   न ह ी ं   ह ो न े   व ा ल ा   ह ै"
# Translation: "you have enough to you you its its its you you secret <EOS>"
#
# Source: "ज ब   म ै ं   ब च ् च ा   थ ा   त ब   क ो ई   भ ी   स ी ट   ब े ल ् ट   न ह ी ं   प ह न त ा   थ ा"
# Translation: "i i i i i i i i <EOS>"
#
# Source: "छ ह   म ै ं   क र   स क त ा   ह ू ँ   द र ् श क   ह ँ स त े   ह ु ए   अ ग र   स ् प ष ् ट त ा   य ि न   ह ै   त ो   अ ब   द े ख त े   ह ै ं   य ा ं ग   क ो   औ र   व ो   ह ै   र ह स ् य"
# Translation: "now six six may i six six six six now may have a six six six six six <EOS>"
#
# Source: "ए न ् स ि न   ट ी र े क ् स   औ र   म ै ं   द ु श ् म न   ए ल ि य न   क े   ह म ल े   क ी   छ ा न ब ी न   क र   र ह े   ह ै ं"
# Translation: "and i are to to <EOS>"
#
# Source: "ट ो क ् य ो   य ह   ह ै"
# Translation: "this is this <EOS>"
#
# Source: "च ि ल ् u d ल ा ह ट   औ र   ह ं स ी"
# Translation: "laughter and <EOS>"
#
# Source: "य ह   भ ा ड ़   म े ं   ज ा ओ"
# Translation: "fuck this <EOS>"
#
# Source: "त ु म   ह म ा र ी   ए क म ा त ् र   व ि क ल ् प   ह ो"
# Translation: "you are you choice <EOS>"
#
# Source: "स ु न व ा ई   प र   उ न ् ह ो ं न े   र े स ् त र ा ं   क ी   स म ी क ् ष ा   भ ी   प ् र स ् त ु त   क ी   र े स ् त र ा ं   क ी   स म ी क ् ष ा"
# Translation: "they they they to to to <EOS>"
#
# Source: "म ी ट ल ग"
# Translation: "meatlug <EOS>"
#
# Source: "व ह   द ू स र ो ं   क े   ल ि ए   क ु छ   क र न ा   च ा ह त ी   थ ी ं"
# Translation: "she want to for that that <EOS>"
#
# Source: "औ र   म े ं   अ म र ी क ा   क ा   व ि त ् त ी य   स ् व ा स ् थ   आ ज   क े   च ि ल ी   ज ै स ा   थ ा"
# Translation: "and the the united states of the united states of the united states <EOS>"
#
# Source: "उ न क ी   आ ँ ख ो ं   क े   स ा थ"
# Translation: "with them them eyes <EOS>"
#
# Source: "ओ ह   स ् ट े स ी"
# Translation: "oh <EOS>"
#
# Source: "ग ़ र ी ब ी   स े   ल े क र   अ म ी र ी   त क   औ र   उ स क े   श ी र ् ष   प र   ह म   प ू र ् व ी   य ू र ो प   क ो   र ख   स क त े   ह ै ं   ह म   प ू र ् व ी   ए श ि य ा   क ो   र ख   स क त े   ह ै ं"
# Translation: "and can can live and and and and and <EOS>"
#
# Source: "ए क   र ा ज ा   स ि क ं द र   प ै द ा   न ह ी ं   ह ु आ   ह ै"
# Translation: "a a a accident <EOS>"
#
# Source: "प र   म े र े   औ र   म ा न व त ा   क े   ल ि ए   क ु छ   औ र   ह ी   ल ि ख ा   थ ा"
# Translation: "but the was something that humanity <EOS>"
#
# Source: "श ् र ो त ा   ब ढ ़ ि य ा"
# Translation: "audience <EOS>"
#
# Source: "ब ग ी च ा   ह म ा र ा   न ह ी ं   ह ै   फ ल   ल े न ा   ग ल त   ह ै"
# Translation: "we fruit are not wrong <EOS>"
#
# Source: "ह ँ स ी   औ र   फ ि र   अ ं त   म े ं   म ु झ े   आ ख र ी   म े ं   ध ् य ा न   द ि ल ा न े   द ी ज ि ए   ए क   व ि च ि त ् र   च ी ज"
# Translation: "and then i finally left me in a school <EOS>"
#
# Source: "ब ह ु त   स ा र े   अ च ् छ े   प ् र य ो ग   ह ु ए   ह ै ं"
# Translation: "lots of are very many <EOS>"
#
# Source: "क ् य ो ं क ि   इ स न े   म ु झ े   न ौ क र ी   द ि ल ा ई"
# Translation: "because i me me <EOS>"
#
# Source: "व े   ह म े ं   ज ू त े   औ र   क ा र   ब े च   र ह े   ह ै"
# Translation: "theyre getting us and car <EOS>"
#
# Source: "त ो   उ न   औ र त ो ं   न े   क ह ा   द े ख ो   ज क ल ि न   न ् य ा म ि र म ् ब ो ं   म े ं   क ौ न   ऐ स ा   ह ो ग ा   ज ो   क ि   ए क   न ा र ं ग ी   ब ा ल ् ट ी   ल े   क र   च ल त ी   ह ु ई   ल म ् ब ी   अ म र ी क ी   औ र त   क े   ह ा थ   स े   स ा म ा न   ख र ी द न ा   न ह ी ं   च ा ह े ग ा   ह ँ स ी   य े   ब ा त   स ो ल ह   आ न े   स ह ी   थ ी"
# Translation: "so one said said said the the said who said this was not as well <EOS>"
#
# Source: "म ै ं   द े ख   र ह ा   ह ू ँ   अ प न ी   ग र ् द न   क े   आ क ा र   क ो   द े ख ो"
# Translation: "i am looking for my my my <EOS>"
#
# Source: "त ु म ् ह ा र े   प ि त ा ज ी"
# Translation: "your daddy daddy <EOS>"
#
# Source: "म े र े   ब े ट े   स े   द ू र   र ह ो"
# Translation: "stay away from my son <EOS>"
#
# Source: "म द द   क र ो"
# Translation: "help <EOS>"
#
# Source: "इ स न े   प ृ थ ् व ी   क े   ट े क ् ट ो न ि क   प ् ल े ट ् स   क ो   स र क ा   द ि य ा   औ र   ह म ा र े   ग ् र ह   क ी   च क ् र ी य   ग त ि   ब ढ ़ ा   द ी   थ ी   औ र   स च   म ु च   म े ं   द ि न   क ी   ल ं ब ा ई   क म   क र   द ी"
# Translation: "it was on earth the the earth of the earth of earth <EOS>"
#
# Source: "क ् य ो ं क ि   ज ब   आ प   अ प न े   श न ि व ा र   व ् य क ् त ि त ् व   क ो   ब ु ध व ा र   क ा म   क र न े   ह े त ु   ल ा   स क त े   ह ै ं   आ प   स ो म व ा र   क ी   औ र   अ ध ि क   इ ं त ज ा र   क र े ं ग े   औ र   उ न   भ ा व न ा ओ ं   क ो   क ि   ह म ा र े   प ा स   स ो म व ा र   क े   ब ा र े   म े ं   ह ै   ह म े ं   म ा न व   ब न ा न े   क ा   ह ि स ् स ा   ह ै ं"
# Translation: "because you you you you you you you you you you you you you <EOS>"
#
# Source: "औ र   म ै ं   स ो च त ी   ह ू ँ   क ी   म ु झ े   य े   स च ् च ा   व ि श ् व ा स   ह ै   क ि   ह म   इ स क ो   ब द ल   स क त े   ह ै ं   ए क   ए क   ह ं स ी   क र क े"
# Translation: "and i think we think we think its a think its a a a a <EOS>"
#
# Source: "न ि र ् म ा ण   क र न े   क ी   क ् ष म त े   स ब स े   स श क ् त   ह ै   ज ो   ए क   व ् य क ् त ि   क ो   ह ो   स क त ी   ह ै"
# Translation: "the best person is build a person can build a person <EOS>"
#
# Source: "म ु झ े   च ू म ो"
# Translation: "kiss me <EOS>"
#
# Source: "प ि छ ल े   स ा ल"
# Translation: "last year last year <EOS>"
#
# Source: "र ा स ् त ा   स ा फ ़   ह ै"
# ...
#
# Source: "प ि त ा ज ी   उ स े   स ु न न े   क े   ल ि ए   न ह ी ं   ह ै"
# Translation: "hes not for for for <EOS>"
#
# Source: "औ र   ह म ा र ी   च ु न ौ त ि य ो ं   क े   द ि ल   म े ं   त ा ल ि य ा ँ   औ र   ह म ा र ी   च ु न ौ त ि य ो ं   क े   द ि ल   म े ं   द ु ब ा र ा   स े   अ प न ी   क ् ष म त ा   क ो   स म झ न ा   औ र   ब ु द ् ध ि म त ् त ा   क ो"
# Translation: "and our heart of your and and and and and and <EOS>"
#
# Source: "आ प   उ न ् ह े ं   अ प न े   आ प   क ो   प ् र श ि क ् ष ि त   क र े ं ग े"
# Translation: "you will to them to <EOS>"
#
# Source: "म े र ी   ज े ब   म े ं   क ् u d य ा   ह ै"
# Translation: "ive been in pocket <EOS>"
#
# Source: "प ि छ ल े   स प ् त ा ह   क े   ल ि ए   त ु म   म ु झ े   छ ू   न ह ी ं   ह र   त र ह   क ा   ब ह ा न ा   ब न ा   द ि य ा   ह ै   औ र   अ ब   प ल   आ   ग य ा   ह ै   आ प   क ु छ   प ा ग ल   क ल ् प न ा   क ा   स ह ा र ा"
# Translation: "the last the went to the me has given me to you you you you you you you me me before you me <EOS>"
#
# Source: "म ु झ े   ल ग त ा   ह ै   क ि   द ु न ि य ा   य ह   क र   स क त ी   ह ै   ज ि स स े   ह म ा र े   ब ा ह र ी   व ि क ा स   क ा   ह म ा र ी   ख ु श ि य ो ं   स े   स ी ध ा   त ा ल म े ल   ह ो   इ स क ा   उ प ा य   य ह   ह ै   क ि   ह म   इ न   ज ा न क ा र ि य ो ं   स े   अ प न े   ह ् र द य   क ो   द ् र व ि त   ह ो न े   द े ं"
# Translation: "i think our could think our our our our our our to world to our our our to world that our to world our world to world to world to world <EOS>"
#
# Source: "D a d   न े   ह म े ं   ब स   ब र ् ब ा द   क र   द ि य ा"
# Translation: "dad dad gave us to dad <EOS>"
#
# Source: "औ र   भ ा र त   ज ो   क र   र ह ा   थ ा   व ो   थ ा   ए क   म ा न द ं ड   ख ड ़ ा   क र न ा   प ू र े   व ि श ् व   म े ं   ब े ह त र   प ् र थ ा ओ ं   क े   स ा म न े   औ र   य ह   ए क   ब ह ु त   ब ड ़ ा   ट ् र े ड म ा र ् क   ब न   ग य ा"
# Translation: "and the was was a india was a world and a and <EOS>"
#
# Source: "अ स ल   म े ं   ह म   व ा स ् त व   म े ं   ए क   द ू स र े   क ो   ज ा न त े   ह ै"
# Translation: "actually we really know one other really one <EOS>"
#
# Source: "य ह   द े ख ो"
# Translation: "look at <EOS>"
#
# Source: "त ु म क ो   क ो ड ़ ा   ल ग न ा   च ा ह ि ए"
# Translation: "you should be a a <EOS>"
#
# Source: "र ि च र ् ड   स ् ट ो क र   औ र   ह ै ल ी   स ् म ि थ   प ि छ ल े   स ो म व ा र   स े   ग ा य ब   ह ै   स प ् त ा ह ा ं त   प र   प र ् व त ा र ो ह ण   क े   ब ा द   स े"
# Translation: "the the is is is is and and and and and the <EOS>"
#
# Source: "औ र   म ै ं   ए क   क ल ा क ा र   थ ा"
# Translation: "and i was an artist <EOS>"
#
# Source: "म ं ग ो ल ि य ा   म े ं   र ा ष ् ट ् र ी य   ड ा क   स े व ा   न े   इ स   प ् र ण ा ल ी   क ो   अ प न ा य ा   ह ै   औ र   अ ब   क ई   ल ो ग ो ं   क े   घ र ो ं   म े ं   ड ा क   प ह ु ँ च ा   र ह े   ह ै ं   प ह ल ी   ब ा र"
# Translation: "now this news this news there news there news this news news this news news <EOS>"
#
# Source: "प ् र ौ द ् य ो ग ि क ी   द ् व ा र ा   ख ा द ् य   अ स ु र क ् ष ि त त ा   क ा   च े ह र ा   ह ी   ब द ल   र ह ा   ह ै   उ न   इ ल ा क ो ं   म े ं   ज ो   ऐ त ि ह ा स ि क   त ौ र   प र   स ू ख े   स े   ग ् र स ् त   ह ै ं"
# Translation: "face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face face f ...
#
# Source: "क ल ा   ए क   उ प म ा   क ो   र च   स क त ी   ह ै"
# Translation: "the can can a a a <EOS>"
#
# Source: "व ह   य ह ा ँ   औ र   व ह ा ँ   उ ड ़   र ह े   थ े   ब ह ु त   ख ु श   ल ग   र ह े   थ े"
# Translation: "she wonderful wonderful there and there were very happy there <EOS>"
#
# Source: "ल े   ज ा ए ँ"
# Translation: "move <EOS>"
#
# Source: "इ स ल ि ए   म ै ं   अ फ ग ा न ि स ् त ा न   ग य ी"
# Translation: "so i made the <EOS>"
#
# Source: "स ् क ॉ ट   म ै ं   आ ज   अ प न े   क प ् त ा न   क े   स ा थ   म ु ल ा क ा त   क ी"
# Translation: "i i captain captain captain captain captain captain captain captain captain captain captain captain captain captain captain captain captain captain captain to captain <EOS>"
#
# Source: "य ह   प ् र ण ा ल ी   इ त न ी   ब ु द ् ध ि म ा न   ह ै   क ि   क ा र   च ल ा न े   क ा   स ब स े   स ु र क ् ष ि त   त र ी क ा   प त ा   ल ग ा   स क त ी   ह ै"
# Translation: "it could the so it system all that that that that system that car system <EOS>"
#
# Source: "व े   अ प न ी   ब े ट ी   क े   ल ि ए   ए क   न य ा   ज ी व न   द े   द ि य ा"
# Translation: "give his daughter for give his daughter <EOS>"
#
# Source: "म ु झ े   ब ु र ा   ल ग   र ह ा   ह ै"
# Translation: "i me feel bad <EOS>"
#
# Source: "औ र   अ ग र   स च   म े ं   फ ़ र ् क   द े ख न ा   ह ै   त ो   आ प   ट ा य ल ट   द े ख े ं"
# Translation: "and if you see you you you <EOS>"
#
# Source: "ए क   आ द म ी   अ प न े   ऋ ण   भ ु ग त ा न   क र त ा   ह ै"
# Translation: "his is man pay for man pay <EOS>"
#
# Source: "त ु म ् ह ा र े   स ा थ   र ह क र"
# Translation: "with you you <EOS>"
#
# Source: "म ै ं   क ह त ा   ह ू ं   ह ा ँ"
# Translation: "i call says yes <EOS>"
#
# Source: "फ ़ ि र   क ु छ   स ौ   स ा ल   प ह ल े   द ो   त र फ ़ ा   स ं च ा र   म े ं   न व ा च ा र   ह ु आ   स ं व ा द ी   म ी ड ि य ा   प ह ल े   त ा र   फ ़ ि र   द ू र भ ा ष"
# Translation: "some hundred years ago ago ago ago but turned into the few years ago <EOS>"
#
# Source: "उ न ् ह ो ं न े   ब त ा य ा   क ि   स भ ् य त ा   क ा   प ् र भ ा व   फ ै ल ा   म र ी ज ो ं   क ी   स ं त ु ष ् ट त ा   ब ढ ़ ी   औ र   व े   औ र ो ं   क ो   भ ी   उ न क े   ब ा र े   म े ं   ब त ा त े"
# Translation: "they spoke was and and and and and and and <EOS>"
#
# Source: "ब ज े   त ी न"
# Translation: "three oclock <EOS>"
#
# Source: "औ र   प त ा   ह ै   क ् य ा"
# Translation: "and what what <EOS>"
#
# Source: "य े   प ू र ी   म ा न व ज ा त ि   क े   ब ा र े   म े ं   ह ै ं"
# Translation: "this all about the <EOS>"
#
# Source: "च क म क   औ र न ा ग आ ं ख े ं"
# Translation: "flint <EOS>"
#
# Source: "म ै ं   क ् य ा   क र   स क त ा   ह ू ँ   व ह   प ू ज ा   स ् थ ल   क े   अ न ् द र   ज ा त ा   ह ै   भ ग व ा न ्   क ् य ा   आ प   म े र ी   म द द   क र ो ग े"
# Translation: "what what what what you can what you could help what you help you you help you help you my <EOS>"
#
# Source: "इ स   अ ँ ध क ा र   प र   र ो श न ी   ड ा ल न े   क े   ल ि ए   ए क   छ ो ट ा   स ा   क द म   उ ठ ा ए ँ   क ् य ो ं क ि   म ै ं न े   द े ख ा   ह ै   अ ँ ध क ा र   क ् य ा   क र   स क त ा   ह ै"
# Translation: "take a step for this step for this step for a a my my my my my my my my my <EOS>"
#
# Source: "क ा ं ग   ख ु द   क ो   म ा र   ड ा ल ा"
# Translation: "himself himself himself <EOS>"
#
# Source: "अ र े   य ह   स ी र म   क ि   आ प   क र   र ह े   ह ै ं   य ह   क ् ष म त ा ओ ं   क ो   प ् र भ ा व ि त   न ह ी ं   ह ै   न ा"
# Translation: "its its its youre not that youre <EOS>"
#
# Source: "ह म ा र ा   ब ै ं क"
# Translation: "bank bank <EOS>"
#
# Source: "व े न   ट ॉ व र   त ब ा ह   आ प   अ प न े   प र ि व ा र   क े   म र न े"
# Translation: "hello you you your your you <EOS>"
#
# Source: "क ् य ा   व ह   व ह ा ँ   ह ो न ा   च ा ह ि ए"
# Translation: "should she be be <EOS>"
#
# Source: "य ह   ह ै   व ो   ज ो   भ ा ष ा   आ प क ो   द े   स क त ी   ह ै"
# Translation: "its can who can language language <EOS>"
#
# Source: "म ै ं   ऊ प र   स े   स ी ध े   ए क   स ं द े श   भ े ज न े   क े   ल ि ए   ए क   न ी च े   ल ा न ा   च ा ह त ा   ह ू ँ"
# Translation: "i want to introduce up straight straight up straight to the straight <EOS>"
#
# Source: "म ै ं   त ु म ् ह े ं   ए क   प ु त ् र   क ी   क ा म न ा   क र त े   ह ै ं"
# Translation: "i do a you a <EOS>"
#
# Source: "व े   अ प न े   ब ा ज ु   व ा ल े   क ी   प ् र स ् त ु त ि   क ो   म ह स ू स   क र   स क त े   ह ै   व ह ा ँ   क ो ई   स ् प ष ् ट   स ं च ा र   न ह ी ं   ह ै"
# Translation: "theyve cannot feel like his own enemy <EOS>"
#
# Source: "स म ् म ो ह न   क ा म   क र े ं ग े"
# Translation: "the work <EOS>"
#
# Source: "म ै ं   अ प न े   क ा र ् य ा ल य   म े ं   ह ो ग ा   प ् र ि य"
# Translation: "i will my my office <EOS>"
#
# Source: "उ स क े   ब ि न ा   म न ु ष ् य   ग ं भ ी र   थ क ा न   त थ ा   ह ड ् ड ि य ा ं म े   क म ज ो र ी   ल ग त ी   ह ै   ज ो   ए क   अ व स ् थ ा   प ै द ा   क र   स क त ी   ह ै   ज ि स क ा   न ा म   ह ै   र ि क े ट ् स"
# Translation: "a a a a a a a a a a a a a a <EOS>"
#
# Source: "म ा ँ   ब ग ़ ी च े   म ै ं   थ ी   म ि ट ट ी   क ो   म ि ल ा   र ह ी   थ ी   औ र   म ै ं   उ न क े   प ा स   म ै ं   ब ै ठ ी   फ ु ल व ा र ी   क ी   म ि ट ् ट ी   स े   ख े ल   र ह ी   थ ी"
# Translation: "the the was had to the the the the and the and playing the the <EOS>"
#
# Source: "त ु म   ब े स ब ॉ ल   ट ो प ी   ह ा   ह ै"
# Translation: "youve read the the <EOS>"
#
# Source: "भ ग व ा न ्   ज ो   प ू र े   ब ् र ह ् म ा ण ् ड   प े   र ा ज   क र त े   ह ै ं   उ न ् ह े ं   म े र ी   र ो ट ी   च ा ह ि ए"
# Translation: "the the god who is my god <EOS>"
#
# Source: "ए ल   म त ल ब   उ त ् त र   द क ् ष ि ण   द क ् ष ि ण   उ त ् त र   ह ै   औ र   ह म   स म ु द ् र   क े   प ा र   क ा र ण   उ त ् त र   स ह न   क र न े   क ी   ज र ू र त   ह ै"
# Translation: "the north the need to turn to north and the north and north and north <EOS>"
#
# Source: "य ह   ए क   ब े ह त र   भ ो ज न   ब न ा त ा   ह ै"
# Translation: "this is a a <EOS>"
#
# Source: "क ृ प य ा   ब ु ल ा ओ"
# Translation: "please call <EOS>"
#
# Source: "म े र ी   अ ं त ि म   ग ा य ब   अ भ ि न य   क े   ल ि ए   स म य   य ह   ह ै"
# Translation: "this final last time <EOS>"
#
# Source: "च ल ो   अ प न े   स े ल   फ ो न"
# Translation: "lets call your phone phone <EOS>"
#
# Source: "क ो ई   अ ं ग ू र   म ा ं ग   र ह ा   ह ै   ज ै स े   क ि   ए क   अ ं ग ् र े ज ़   क ो ई   ए न े ब   म ा ं ग   र ह ा   ह ै   औ र   क ो ई   ग ् र े प ् स   म ा ं ग   र ह ा   ह ै"
# Translation: "no jim is like someone <EOS>"
#
# Source: "उ न ् ह ो ं न े   क ह ा   क ि   ल ै प ट ॉ प   प र   ए क   ज ा द ू ग र   क े"
# Translation: "he said one of one of <EOS>"
#
# Source: "म ै ं   प त ् र   म े ं   उ स   ड ा ल   द े ं ग े"
# Translation: "i will put in the <EOS>"
#
# Source: "भ य भ ी त   म ु श ् क ि ल ो ं   क ा   स ा म न ा   क र न ा   प ड ़   ज ़ ् य ा द ा"
# Translation: "but faced to much <EOS>"
#
# Source: "क ौ न   म ै ं"
# Translation: "who i i <EOS>"
#
# Source: "म ह ो द य   म ै ं   अ स ् प त ा ल   क ो   फ ो न   क र न े   क ी   ज र ू र त   ह ै"
# Translation: "sir i need to call to hospital to hospital <EOS>"
#
# Source: "य े   त न ् ज ़ ा न ि य ा   क ी   स ब स े   ब ड ी   क ं प न ी   ह ै"
# Translation: "that is of of <EOS>"
#
# Source: "ठ ी क   ह ै   क ै स े   इ स   ब ा र े   म े ं"
# Translation: "how how about this about <EOS>"
#
# Source: "उ ल ् ल ं घ न   आ ं द ो ल न"
# Translation: "ella <EOS>"
#
# Source: "क ा म न ा   क र त ा   ह ू ँ   आ प क ो   आ प क ा   ब े ट ा   म ि ल   ज ा ए"
# Translation: "i find the father and your son <EOS>"
#
# Source: "च ल ो   S a r u"
# Translation: "come saru <EOS>"
#
# Source: "क ् य ा   ह ु आ   ड ै ड"
# Translation: "what happened <EOS>"
#
# Source: "आ प   ए क   ज ु आ   आ द म ी   स ा इ म न   ह ै ं"
# Translation: "you you a man for a <EOS>"
#
# Source: "त ो   क ि   क ् र ी प ् ट ो ण   फ ि र   स े   र ह   स क त े   ह ै ं   प ृ थ ् व ी   प र"
# Translation: "so if you can earth for earth <EOS>"
#
# Source: "आ प   ठ ी क   ह ै ं   ह म   स ु र क ् ष ि त   ह ै ं"
# Translation: "youre safe okay <EOS>"
#
# Source: "य ह   म ा न ा   ज ा त ा   थ ा   क ् य ा   य ह ी   ह ै"
# Translation: "its what it was supposed <EOS>"
#
# Source: "उ स न े   म ु झ े   क स म   ख ि ल ा य ी"
# Translation: "he swear me <EOS>"
#
# Source: "आ प   अ प न े   प र ि व ा र   क े   ल ि ए   श ब ् द   म ि ल   स क त ा   ह ै"
# Translation: "you you have for you you your <EOS>"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-2a5eff2ec72d> in <module>()
#       2 file1 = open("/content/drive/MyDrive/answer_27.txt","w")
#       3 for source,  x in examples:
# ----> 4     output_words, attentions = evaluate_test(encoder1, attn_decoder1, x)
#       5     output_sentence = ' '.join(output_words)
#       6     source = ' '.join(source)
#
# <ipython-input-32-61fa333b7ae8> in evaluate_test(encoder, decoder, input_tensor, max_length)
#      17
#      18         decoded_words = []
# ---> 19         decoder_attentions = torch.zeros(max_length, max_length)
#      20
#      21         for di in range(max_length):
#
# KeyboardInterrupt:
